# %% [markdown]
# ### Clust PC example notebook
# Requirements: causallearn

# %%
# !pip install causal-learn
# %load_ext autoreload
# !pip install Ipython --upgrade
# !pip install autoreload
# !pip install networkx
# !pip install gcastle
# Out:
# Requirement already satisfied: causal-learn in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (0.1.3.3)
# Requirement already satisfied: networkx in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from causal-learn) (3.1)
# Requirement already satisfied: pydot in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from causal-learn) (1.4.2)
# Requirement already satisfied: numpy in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from causal-learn) (1.23.0)
# Requirement already satisfied: pandas in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from causal-learn) (1.4.3)
# Requirement already satisfied: matplotlib in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from causal-learn) (3.5.2)
# Requirement already satisfied: tqdm in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from causal-learn) (4.65.0)
# Requirement already satisfied: scikit-learn in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from causal-learn) (1.1.1)
# Requirement already satisfied: graphviz in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from causal-learn) (0.20.1)
# Requirement already satisfied: statsmodels in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from causal-learn) (0.13.5)
# Requirement already satisfied: scipy in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from causal-learn) (1.8.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from matplotlib->causal-learn) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from matplotlib->causal-learn) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from matplotlib->causal-learn) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from matplotlib->causal-learn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from matplotlib->causal-learn) (1.4.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from matplotlib->causal-learn) (23.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from matplotlib->causal-learn) (4.34.3)
# Requirement already satisfied: six>=1.5 in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from python-dateutil>=2.7->matplotlib->causal-learn) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from pandas->causal-learn) (2022.1)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from scikit-learn->causal-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from scikit-learn->causal-learn) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from statsmodels->causal-learn) (0.5.3)
# Requirement already satisfied: colorama in c:\users\janmarco\mlprojects\masterthesis\masterthesis\mthesis\lib\site-packages (from tqdm->causal-learn) (0.4.5)
# WARNING: You are using pip version 21.2.3; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\mthesis\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# %cd ..
# Out:
# c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis

# %%
# %load_ext autoreload # Depending on environment might not be necessary
# %autoreload 2
# from ipython import autoreload
import numpy as np
import causallearn
import random
from clustcausal.algs.clust_pc import ClustPC
from clustcausal.clusterdag.cluster_dag import CDAG
from clustcausal.utils.utils import *
# Out:
# UsageError: Line magic function `%autoreload` not found.

# %%
# Define the nodes (have to be in topological ordering):
nodes = ['X1', 'X2', 'X3', 'Y1', 'Y2', 'Z1', 'Z2', 'Z3']
# nodes = ['X1', 'Y1', 'Z1', 'Z2', 'Z3']
# Define the edges (have to be in topological ordering):
edges = [('X1', 'X2'), ('X3', 'X2'), ('X3', 'Z3'), ('X2', 'Z2'), ('X1','Z1'), ('Y1','Z1'), ('Y2', 'Z2'), ('Y1','Z2'), ('Z1','Z2'), ('Z2','Z3')]
# edges = [('X1','Z1'), ('Y1','Z1'), ('Y1','Z2'), ('Z1','Z2'), ('Z2','Z3')]
# Define the cluster mapping:
cluster_mapping = {'X': ['X1', 'X2', 'X3'], 'Y': ['Y1', 'Y2'], 'Z': ['Z1', 'Z2', 'Z3']}
# cluster_mapping = {'X': ['X1'], 'Y': ['Y1'], 'Z': ['Z1', 'Z2', 'Z3']}
no_clust_mapping = {'A' : ['X1', 'X2', 'X3', 'Y1', 'Y2', 'Z1', 'Z2', 'Z3']}
no_clust_edges = []
# Define the cluster edges:
cluster_edges = [('X', 'Z'), ('Y', 'Z')]

# %%
# # Further example C-DAGs
# perfect_cluster_mapping = {'C1': ['X1'], 'C2': ['X2'], 'C3': ['X3'], \
#                    'C4': ['X4'], 'C5': ['X5'], 'C6': ['X6'], 'C7': ['X7']}
# perfect_cluster_edges = [('C1', 'C2'), ('C2', 'C3'), ('C3', 'C4'), ('C4', 'C5'), \
#                  ('C1', 'C6'), ('C4', 'C6'), ('C5', 'C6'), ('C1', 'C7'), \
#                     ('C2', 'C7'), ('C6', 'C7')]
# # Or, an actual C-DAG
# cluster_mapping = {'C1': ['X1', 'X2', 'X3'], 'C2': ['X4', 'X5'], 'C3': ['X6', 'X7']}
# cluster_edges = [('C1', 'C2'), ('C1', 'C3'), ('C2', 'C3')]
# # Cluster mapping for 4 variables
# # cluster_mapping = {'C1': ['X1', 'X2'], 'C2':['X3','X4']}
# # cluster_edges = [('C1', 'C2')]
# cdag = CDAG(perfect_cluster_mapping, perfect_cluster_edges)
# cdag = CDAG(cluster_mapping, cluster_edges)
# cdag.node_names
# cdag.draw_cluster_graph()

# %%
# Draw the ground truth graph
draw_graph(nodes, edges)
# Out:
# INFO: oriented edge: (X1,X2)
# INFO: removed edge: (X1,X3)
# INFO: removed edge: (X1,Y1)
# INFO: removed edge: (X1,Y2)
# INFO: oriented edge: (X1,Z1)
# INFO: removed edge: (X1,Z2)
# INFO: removed edge: (X1,Z3)
# INFO: removed edge: (X2,X3)
# INFO: removed edge: (X2,Y1)
# INFO: removed edge: (X2,Y2)
# INFO: removed edge: (X2,Z1)
# INFO: oriented edge: (X2,Z2)
# INFO: removed edge: (X2,Z3)
# INFO: removed edge: (X3,Y1)
# INFO: removed edge: (X3,Y2)
# INFO: removed edge: (X3,Z1)
# INFO: removed edge: (X3,Z2)
# INFO: oriented edge: (X3,Z3)
# INFO: removed edge: (Y1,Y2)
# INFO: oriented edge: (Y1,Z1)
# INFO: oriented edge: (Y1,Z2)
# INFO: removed edge: (Y1,Z3)
# INFO: removed edge: (Y2,Z1)
# INFO: oriented edge: (Y2,Z2)
# INFO: removed edge: (Y2,Z3)
# INFO: oriented edge: (Z1,Z2)
# INFO: removed edge: (Z1,Z3)
# INFO: oriented edge: (Z2,Z3)

# %%
# Draw the cluster graph
cdag = CDAG(cluster_mapping, cluster_edges)
cdag.cluster_graph.draw_pydot_graph()
# Out:
# INFO: removed edge: (X,Y)
# INFO: oriented edge: (X,Z)
# INFO: oriented edge: (Y,Z)

# %%
# Generate Gaussian ANM
# Example edge_weights, if None is given, they will be generated randomly
# edge_weights = {('X1', 'Z1'): 1, ('Y1', 'Z1'): 2, ('Y1', 'Z2'): 1, ('Z1', 'Z2'): -3, ('Z2', 'Z3'): 2}
edge_weights = None
data, edge_weights = generate_gaussian_anm(nodes, edges, edge_weights = edge_weights)
print(data.shape, edge_weights)
# Out:
# (10000, 8) {('X1', 'X2'): -2, ('X3', 'X2'): -3, ('X3', 'Z3'): 1, ('X2', 'Z2'): -2, ('X1', 'Z1'): -3, ('Y1', 'Z1'): 3, ('Y2', 'Z2'): 3, ('Y1', 'Z2'): 2, ('Z1', 'Z2'): 1, ('Z2', 'Z3'): 2}

# %%
# # For illustrative purposes, get mpdag and draw it manually (usually ClustPC handles this)
# mpdag = cdag.cdag_to_mpdag()
# cdag.draw_mpdag()

# %%
# Run ClustPC
# %autoreload 2
clustpc = ClustPC(cdag = cdag, data = data, alpha = 0.05, \
                  indep_test = "fisherz", \
                  verbose = True, show_progress=True)
# Out:
# INFO: removed edge: (X1,Y1)
# INFO: removed edge: (X1,Y2)
# INFO: oriented edge: (X1,Z1)
# INFO: oriented edge: (X1,Z2)
# INFO: oriented edge: (X1,Z3)
# INFO: removed edge: (X2,Y1)
# INFO: removed edge: (X2,Y2)
# INFO: oriented edge: (X2,Z1)
# INFO: oriented edge: (X2,Z2)
# INFO: oriented edge: (X2,Z3)
# INFO: removed edge: (X3,Y1)
# INFO: removed edge: (X3,Y2)
# INFO: oriented edge: (X3,Z1)
# INFO: oriented edge: (X3,Z2)
# INFO: oriented edge: (X3,Z3)
# INFO: oriented edge: (Y1,Z1)
# INFO: oriented edge: (Y1,Z2)
# INFO: oriented edge: (Y1,Z3)
# INFO: oriented edge: (Y2,Z1)
# INFO: oriented edge: (Y2,Z2)
# INFO: oriented edge: (Y2,Z3)

# %%
clustpc.cdag.cdag_list_of_topological_sort
# Out:
# ['X', 'Y', 'Z']

# %%
result_cdag = clustpc.run()
# Out:
# Beginning work on cluster X
#
# Intra phase in cluster X
# Cluster node indices are [0 1 2]
# Local graph node indices are [0 1 2]
# Depth=1, working on node 2: 100%|██████████| 3/3 [00:00<00:00, 753.87it/s]
# Neighbors of 0 in X are [1 2]
# Testing edges from 0 to 1
# 0 dep 1 | () with p-value 0.000000
# Testing edges from 0 to 2
# 0 ind 2 | () with p-value 0.119934
# Neighbors of 1 in X are [0 2]
# Testing edges from 1 to 0
# 1 dep 0 | () with p-value 0.000000
# Testing edges from 1 to 2
# 1 ind 2 | () with p-value 0.308183
# Neighbors of 2 in X are [0 1]
# Testing edges from 2 to 0
# 2 ind 0 | () with p-value 0.119934
# Testing edges from 2 to 1
# 2 ind 1 | () with p-value 0.308183
# Deleted edge from 0 to 2
# Deleted edge from 1 to 2
# Neighbors of 0 in X are [1]
# Testing edges from 0 to 1
# 0 dep 1 | (2,) with p-value 0.000000
# Neighbors of 1 in X are [0]
# Testing edges from 1 to 0
# 1 dep 0 | (2,) with p-value 0.000000
# Neighbors of 2 in X are []
#
# Beginning work on cluster Y
#
# Intra phase in cluster Y
# Cluster node indices are [3 4]
# Local graph node indices are [3 4]
# Depth=0, working on node 4: 100%|██████████| 2/2 [00:00<00:00, 500.24it/s]
# Neighbors of 3 in Y are [4]
# Testing edges from 3 to 4
# 3 ind 4 | () with p-value 0.534931
# Neighbors of 4 in Y are [3]
# Testing edges from 4 to 3
# 4 ind 3 | () with p-value 0.534931
# Deleted edge from 3 to 4
#
# Beginning work on cluster Z
#
# Inter phase between low cluster Z and parent X
# Cluster node indices are [0 1 2 5 6 7]
# Local graph node indices are [0 1 2 5 6 7]
# Depth=5, working on node 6:  83%|████████▎ | 5/6 [00:00<00:00, 454.86it/s]
# Neighbors of 0 in (Z,X) are [1 5 6 7]
# Testing edges from 0 to 1
# 0 dep 1 | () with p-value 0.000000
# Testing edges from 0 to 5
# 0 dep 5 | () with p-value 0.000000
# Testing edges from 0 to 6
# 0 dep 6 | () with p-value 0.000000
# Testing edges from 0 to 7
# 0 dep 7 | () with p-value 0.000000
# Neighbors of 1 in (Z,X) are [0 5 6 7]
# Testing edges from 1 to 0
# 1 dep 0 | () with p-value 0.000000
# Testing edges from 1 to 5
# 1 dep 5 | () with p-value 0.000000
# Testing edges from 1 to 6
# 1 dep 6 | () with p-value 0.000000
# Testing edges from 1 to 7
# 1 dep 7 | () with p-value 0.000000
# Neighbors of 2 in (Z,X) are [5 6 7]
# Testing edges from 2 to 5
# 2 ind 5 | () with p-value 0.179920
# Testing edges from 2 to 6
# 2 ind 6 | () with p-value 0.822226
# Testing edges from 2 to 7
# 2 dep 7 | () with p-value 0.000000
# Neighbors of 5 in (Z,X) are [0 1 2 6 7]
# Testing edges from 5 to 0
# 5 dep 0 | () with p-value 0.000000
# Testing edges from 5 to 1
# 5 dep 1 | () with p-value 0.000000
# Testing edges from 5 to 2
# 5 ind 2 | () with p-value 0.179920
# Testing edges from 5 to 6
# 5 dep 6 | () with p-value 0.000000
# Testing edges from 5 to 7
# 5 dep 7 | () with p-value 0.000000
# Neighbors of 6 in (Z,X) are [0 1 2 5 7]
# Testing edges from 6 to 0
# 6 dep 0 | () with p-value 0.000000
# Testing edges from 6 to 1
# 6 dep 1 | () with p-value 0.000000
# Testing edges from 6 to 2
# 6 ind 2 | () with p-value 0.822226
# Testing edges from 6 to 5
# 6 dep 5 | () with p-value 0.000000
# Testing edges from 6 to 7
# 6 dep 7 | () with p-value 0.000000
# Neighbors of 7 in (Z,X) are [0 1 2 5 6]
# Testing edges from 7 to 0
# 7 dep 0 | () with p-value 0.000000
# Testing edges from 7 to 1
# 7 dep 1 | () with p-value 0.000000
# Testing edges from 7 to 2
# 7 dep 2 | () with p-value 0.000000
# Testing edges from 7 to 5
# 7 dep 5 | () with p-value 0.000000
# Testing edges from 7 to 6
# 7 dep 6 | () with p-value 0.000000
# Deleted edge from Z2 to X3
# Deleted edge from X3 to Z1
# Neighbors of 0 in (Z,X) are [1 5 6 7]
# Testing edges from 0 to 1
# 0 dep 1 | (2,) with p-value 0.000000
# 0 dep 1 | (3,) with p-value 0.000000
# 0 dep 1 | (4,) with p-value 0.000000
# 0 dep 1 | (5,) with p-value 0.000000
# 0 dep 1 | (6,) with p-value 0.000000
# 0 dep 1 | (7,) with p-value 0.000000
# Testing edges from 0 to 5
# 0 dep 5 | (1,) with p-value 0.000000
# 0 dep 5 | (2,) with p-value 0.000000
# 0 dep 5 | (3,) with p-value 0.000000
# 0 dep 5 | (4,) with p-value 0.000000
# 0 dep 5 | (6,) with p-value 0.000000
# 0 dep 5 | (7,) with p-value 0.000000
# Testing edges from 0 to 6
# 0 dep 6 | (1,) with p-value 0.000000
# 0 dep 6 | (2,) with p-value 0.000000
# 0 dep 6 | (3,) with p-value 0.000000
# 0 dep 6 | (4,) with p-value 0.000000
# 0 dep 6 | (5,) with p-value 0.000000
# 0 ind 6 | (7,) with p-value 0.156006
# Testing edges from 0 to 7
# 0 dep 7 | (1,) with p-value 0.000000
# 0 dep 7 | (2,) with p-value 0.000000
# 0 dep 7 | (3,) with p-value 0.000000
# 0 dep 7 | (4,) with p-value 0.000000
# 0 dep 7 | (5,) with p-value 0.000000
# 0 ind 7 | (6,) with p-value 0.860779
# Neighbors of 1 in (Z,X) are [0 5 6 7]
# Testing edges from 1 to 0
# 1 dep 0 | (2,) with p-value 0.000000
# 1 dep 0 | (3,) with p-value 0.000000
# 1 dep 0 | (4,) with p-value 0.000000
# 1 dep 0 | (5,) with p-value 0.000000
# 1 dep 0 | (6,) with p-value 0.000000
# 1 dep 0 | (7,) with p-value 0.000000
# Testing edges from 1 to 5
# 1 ind 5 | (0,) with p-value 0.727972
# 1 dep 5 | (2,) with p-value 0.000000
# 1 dep 5 | (3,) with p-value 0.000000
# 1 dep 5 | (4,) with p-value 0.000000
# 1 dep 5 | (6,) with p-value 0.000000
# 1 dep 5 | (7,) with p-value 0.000000
# Testing edges from 1 to 6
# 1 dep 6 | (0,) with p-value 0.000000
# 1 dep 6 | (2,) with p-value 0.000000
# 1 dep 6 | (3,) with p-value 0.000000
# 1 dep 6 | (4,) with p-value 0.000000
# 1 dep 6 | (5,) with p-value 0.000000
# 1 dep 6 | (7,) with p-value 0.005033
# Testing edges from 1 to 7
# 1 dep 7 | (0,) with p-value 0.000000
# 1 dep 7 | (2,) with p-value 0.000000
# 1 dep 7 | (3,) with p-value 0.000000
# 1 dep 7 | (4,) with p-value 0.000000
# 1 dep 7 | (5,) with p-value 0.000000
# 1 ind 7 | (6,) with p-value 0.809620
# Neighbors of 2 in (Z,X) are [7]
# Testing edges from 2 to 7
# 2 dep 7 | (0,) with p-value 0.000000
# 2 dep 7 | (1,) with p-value 0.000000
# 2 dep 7 | (3,) with p-value 0.000000
# 2 dep 7 | (4,) with p-value 0.000000
# 2 dep 7 | (5,) with p-value 0.000000
# 2 dep 7 | (6,) with p-value 0.000000
# Neighbors of 5 in (Z,X) are [0 1 6 7]
# Testing edges from 5 to 0
# 5 dep 0 | (1,) with p-value 0.000000
# 5 dep 0 | (2,) with p-value 0.000000
# 5 dep 0 | (3,) with p-value 0.000000
# 5 dep 0 | (4,) with p-value 0.000000
# 5 dep 0 | (6,) with p-value 0.000000
# 5 dep 0 | (7,) with p-value 0.000000
# Testing edges from 5 to 1
# 5 ind 1 | (0,) with p-value 0.727972
# 5 dep 1 | (2,) with p-value 0.000000
# 5 dep 1 | (3,) with p-value 0.000000
# 5 dep 1 | (4,) with p-value 0.000000
# 5 dep 1 | (6,) with p-value 0.000000
# 5 dep 1 | (7,) with p-value 0.000000
# Testing edges from 5 to 6
# 5 dep 6 | (0,) with p-value 0.000000
# 5 dep 6 | (1,) with p-value 0.000000
# 5 dep 6 | (2,) with p-value 0.000000
# 5 dep 6 | (3,) with p-value 0.000000
# 5 dep 6 | (4,) with p-value 0.000000
# 5 dep 6 | (7,) with p-value 0.000000
# Testing edges from 5 to 7
# 5 dep 7 | (0,) with p-value 0.000000
# 5 dep 7 | (1,) with p-value 0.000000
# 5 dep 7 | (2,) with p-value 0.000000
# 5 dep 7 | (3,) with p-value 0.000000
# 5 dep 7 | (4,) with p-value 0.000000
# 5 ind 7 | (6,) with p-value 0.878041
# Neighbors of 6 in (Z,X) are [0 1 5 7]
# Testing edges from 6 to 0
# 6 dep 0 | (1,) with p-value 0.000000
# 6 dep 0 | (2,) with p-value 0.000000
# 6 dep 0 | (3,) with p-value 0.000000
# 6 dep 0 | (4,) with p-value 0.000000
# 6 dep 0 | (5,) with p-value 0.000000
# 6 ind 0 | (7,) with p-value 0.156006
# Testing edges from 6 to 1
# 6 dep 1 | (0,) with p-value 0.000000
# 6 dep 1 | (2,) with p-value 0.000000
# 6 dep 1 | (3,) with p-value 0.000000
# 6 dep 1 | (4,) with p-value 0.000000
# 6 dep 1 | (5,) with p-value 0.000000
# 6 dep 1 | (7,) with p-value 0.005033
# Testing edges from 6 to 5
# 6 dep 5 | (0,) with p-value 0.000000
# 6 dep 5 | (1,) with p-value 0.000000
# 6 dep 5 | (2,) with p-value 0.000000
# 6 dep 5 | (3,) with p-value 0.000000
# 6 dep 5 | (4,) with p-value 0.000000
# 6 dep 5 | (7,) with p-value 0.000000
# Testing edges from 6 to 7
# 6 dep 7 | (0,) with p-value 0.000000
# 6 dep 7 | (1,) with p-value 0.000000
# 6 dep 7 | (2,) with p-value 0.000000
# 6 dep 7 | (3,) with p-value 0.000000
# 6 dep 7 | (4,) with p-value 0.000000
# 6 dep 7 | (5,) with p-value 0.000000
# Neighbors of 7 in (Z,X) are [0 1 2 5 6]
# Testing edges from 7 to 0
# 7 dep 0 | (1,) with p-value 0.000000
# 7 dep 0 | (2,) with p-value 0.000000
# 7 dep 0 | (3,) with p-value 0.000000
# 7 dep 0 | (4,) with p-value 0.000000
# 7 dep 0 | (5,) with p-value 0.000000
# 7 ind 0 | (6,) with p-value 0.860779
# Testing edges from 7 to 1
# 7 dep 1 | (0,) with p-value 0.000000
# 7 dep 1 | (2,) with p-value 0.000000
# 7 dep 1 | (3,) with p-value 0.000000
# 7 dep 1 | (4,) with p-value 0.000000
# 7 dep 1 | (5,) with p-value 0.000000
# 7 ind 1 | (6,) with p-value 0.809620
# Testing edges from 7 to 2
# 7 dep 2 | (0,) with p-value 0.000000
# 7 dep 2 | (1,) with p-value 0.000000
# 7 dep 2 | (3,) with p-value 0.000000
# 7 dep 2 | (4,) with p-value 0.000000
# 7 dep 2 | (5,) with p-value 0.000000
# 7 dep 2 | (6,) with p-value 0.000000
# Testing edges from 7 to 5
# 7 dep 5 | (0,) with p-value 0.000000
# 7 dep 5 | (1,) with p-value 0.000000
# 7 dep 5 | (2,) with p-value 0.000000
# 7 dep 5 | (3,) with p-value 0.000000
# 7 dep 5 | (4,) with p-value 0.000000
# 7 ind 5 | (6,) with p-value 0.878041
# Testing edges from 7 to 6
# 7 dep 6 | (0,) with p-value 0.000000
# 7 dep 6 | (1,) with p-value 0.000000
# 7 dep 6 | (2,) with p-value 0.000000
# 7 dep 6 | (3,) with p-value 0.000000
# 7 dep 6 | (4,) with p-value 0.000000
# 7 dep 6 | (5,) with p-value 0.000000
# Deleted edge from X1 to Z3
# Deleted edge from Z3 to X2
# Deleted edge from X2 to Z1
# Deleted edge from Z1 to Z3
# Deleted edge from X1 to Z2
# Neighbors of 0 in (Z,X) are [1 5]
# Testing edges from 0 to 1
# 0 dep 1 | (2, 3) with p-value 0.000000
# 0 dep 1 | (2, 4) with p-value 0.000000
# 0 dep 1 | (2, 5) with p-value 0.000000
# 0 dep 1 | (2, 6) with p-value 0.000000
# 0 dep 1 | (2, 7) with p-value 0.000000
# 0 dep 1 | (3, 4) with p-value 0.000000
# 0 dep 1 | (3, 5) with p-value 0.000000
# 0 dep 1 | (3, 6) with p-value 0.000000
# 0 dep 1 | (3, 7) with p-value 0.000000
# 0 dep 1 | (4, 5) with p-value 0.000000
# 0 dep 1 | (4, 6) with p-value 0.000000
# 0 dep 1 | (4, 7) with p-value 0.000000
# 0 dep 1 | (5, 6) with p-value 0.000000
# 0 dep 1 | (5, 7) with p-value 0.000000
# 0 dep 1 | (6, 7) with p-value 0.000000
# Testing edges from 0 to 5
# 0 dep 5 | (1, 2) with p-value 0.000000
# 0 dep 5 | (1, 3) with p-value 0.000000
# 0 dep 5 | (1, 4) with p-value 0.000000
# 0 dep 5 | (1, 6) with p-value 0.000000
# 0 dep 5 | (1, 7) with p-value 0.000000
# 0 dep 5 | (2, 3) with p-value 0.000000
# 0 dep 5 | (2, 4) with p-value 0.000000
# 0 dep 5 | (2, 6) with p-value 0.000000
# 0 dep 5 | (2, 7) with p-value 0.000000
# 0 dep 5 | (3, 4) with p-value 0.000000
# 0 dep 5 | (3, 6) with p-value 0.000000
# 0 dep 5 | (3, 7) with p-value 0.000000
# 0 dep 5 | (4, 6) with p-value 0.000000
# 0 dep 5 | (4, 7) with p-value 0.000000
# 0 dep 5 | (6, 7) with p-value 0.000000
# Neighbors of 1 in (Z,X) are [0 6]
# Testing edges from 1 to 0
# 1 dep 0 | (2, 3) with p-value 0.000000
# 1 dep 0 | (2, 4) with p-value 0.000000
# 1 dep 0 | (2, 5) with p-value 0.000000
# 1 dep 0 | (2, 6) with p-value 0.000000
# 1 dep 0 | (2, 7) with p-value 0.000000
# 1 dep 0 | (3, 4) with p-value 0.000000
# 1 dep 0 | (3, 5) with p-value 0.000000
# 1 dep 0 | (3, 6) with p-value 0.000000
# 1 dep 0 | (3, 7) with p-value 0.000000
# 1 dep 0 | (4, 5) with p-value 0.000000
# 1 dep 0 | (4, 6) with p-value 0.000000
# 1 dep 0 | (4, 7) with p-value 0.000000
# 1 dep 0 | (5, 6) with p-value 0.000000
# 1 dep 0 | (5, 7) with p-value 0.000000
# 1 dep 0 | (6, 7) with p-value 0.000000
# Testing edges from 1 to 6
# 1 dep 6 | (0, 2) with p-value 0.000000
# 1 dep 6 | (0, 3) with p-value 0.000000
# 1 dep 6 | (0, 4) with p-value 0.000000
# 1 dep 6 | (0, 5) with p-value 0.000000
# 1 dep 6 | (0, 7) with p-value 0.000452
# 1 dep 6 | (2, 3) with p-value 0.000000
# 1 dep 6 | (2, 4) with p-value 0.000000
# 1 dep 6 | (2, 5) with p-value 0.000000
# 1 ind 6 | (2, 7) with p-value 0.465540
# 1 dep 6 | (3, 4) with p-value 0.000000
# 1 dep 6 | (3, 5) with p-value 0.000000
# 1 dep 6 | (3, 7) with p-value 0.000000
# 1 dep 6 | (4, 5) with p-value 0.000000
# 1 dep 6 | (4, 7) with p-value 0.000251
# 1 dep 6 | (5, 7) with p-value 0.000000
# Neighbors of 2 in (Z,X) are [7]
# Testing edges from 2 to 7
# 2 dep 7 | (0, 1) with p-value 0.000000
# 2 dep 7 | (0, 3) with p-value 0.000000
# 2 dep 7 | (0, 4) with p-value 0.000000
# 2 dep 7 | (0, 5) with p-value 0.000000
# 2 dep 7 | (0, 6) with p-value 0.000000
# 2 dep 7 | (1, 3) with p-value 0.000000
# 2 dep 7 | (1, 4) with p-value 0.000000
# 2 dep 7 | (1, 5) with p-value 0.000000
# 2 dep 7 | (1, 6) with p-value 0.000000
# 2 dep 7 | (3, 4) with p-value 0.000000
# 2 dep 7 | (3, 5) with p-value 0.000000
# 2 dep 7 | (3, 6) with p-value 0.000000
# 2 dep 7 | (4, 5) with p-value 0.000000
# 2 dep 7 | (4, 6) with p-value 0.000000
# 2 dep 7 | (5, 6) with p-value 0.000000
# Neighbors of 5 in (Z,X) are [0 6]
# Testing edges from 5 to 0
# 5 dep 0 | (1, 2) with p-value 0.000000
# 5 dep 0 | (1, 3) with p-value 0.000000
# 5 dep 0 | (1, 4) with p-value 0.000000
# 5 dep 0 | (1, 6) with p-value 0.000000
# 5 dep 0 | (1, 7) with p-value 0.000000
# 5 dep 0 | (2, 3) with p-value 0.000000
# 5 dep 0 | (2, 4) with p-value 0.000000
# 5 dep 0 | (2, 6) with p-value 0.000000
# 5 dep 0 | (2, 7) with p-value 0.000000
# 5 dep 0 | (3, 4) with p-value 0.000000
# 5 dep 0 | (3, 6) with p-value 0.000000
# 5 dep 0 | (3, 7) with p-value 0.000000
# 5 dep 0 | (4, 6) with p-value 0.000000
# 5 dep 0 | (4, 7) with p-value 0.000000
# 5 dep 0 | (6, 7) with p-value 0.000000
# Testing edges from 5 to 6
# 5 dep 6 | (0, 1) with p-value 0.000000
# 5 dep 6 | (0, 2) with p-value 0.000000
# 5 dep 6 | (0, 3) with p-value 0.000000
# 5 dep 6 | (0, 4) with p-value 0.000000
# 5 dep 6 | (0, 7) with p-value 0.000000
# 5 dep 6 | (1, 2) with p-value 0.000000
# 5 dep 6 | (1, 3) with p-value 0.000000
# 5 dep 6 | (1, 4) with p-value 0.000000
# 5 dep 6 | (1, 7) with p-value 0.000000
# 5 dep 6 | (2, 3) with p-value 0.000000
# 5 dep 6 | (2, 4) with p-value 0.000000
# 5 dep 6 | (2, 7) with p-value 0.000000
# 5 dep 6 | (3, 4) with p-value 0.000000
# 5 dep 6 | (3, 7) with p-value 0.014944
# 5 dep 6 | (4, 7) with p-value 0.000000
# Neighbors of 6 in (Z,X) are [1 5 7]
# Testing edges from 6 to 1
# 6 dep 1 | (0, 2) with p-value 0.000000
# 6 dep 1 | (0, 3) with p-value 0.000000
# 6 dep 1 | (0, 4) with p-value 0.000000
# 6 dep 1 | (0, 5) with p-value 0.000000
# 6 dep 1 | (0, 7) with p-value 0.000452
# 6 dep 1 | (2, 3) with p-value 0.000000
# 6 dep 1 | (2, 4) with p-value 0.000000
# 6 dep 1 | (2, 5) with p-value 0.000000
# 6 ind 1 | (2, 7) with p-value 0.465540
# 6 dep 1 | (3, 4) with p-value 0.000000
# 6 dep 1 | (3, 5) with p-value 0.000000
# 6 dep 1 | (3, 7) with p-value 0.000000
# 6 dep 1 | (4, 5) with p-value 0.000000
# 6 dep 1 | (4, 7) with p-value 0.000251
# 6 dep 1 | (5, 7) with p-value 0.000000
# Testing edges from 6 to 5
# 6 dep 5 | (0, 1) with p-value 0.000000
# 6 dep 5 | (0, 2) with p-value 0.000000
# 6 dep 5 | (0, 3) with p-value 0.000000
# 6 dep 5 | (0, 4) with p-value 0.000000
# 6 dep 5 | (0, 7) with p-value 0.000000
# 6 dep 5 | (1, 2) with p-value 0.000000
# 6 dep 5 | (1, 3) with p-value 0.000000
# 6 dep 5 | (1, 4) with p-value 0.000000
# 6 dep 5 | (1, 7) with p-value 0.000000
# 6 dep 5 | (2, 3) with p-value 0.000000
# 6 dep 5 | (2, 4) with p-value 0.000000
# 6 dep 5 | (2, 7) with p-value 0.000000
# 6 dep 5 | (3, 4) with p-value 0.000000
# 6 dep 5 | (3, 7) with p-value 0.014944
# 6 dep 5 | (4, 7) with p-value 0.000000
# Testing edges from 6 to 7
# 6 dep 7 | (0, 1) with p-value 0.000000
# 6 dep 7 | (0, 2) with p-value 0.000000
# 6 dep 7 | (0, 3) with p-value 0.000000
# 6 dep 7 | (0, 4) with p-value 0.000000
# 6 dep 7 | (0, 5) with p-value 0.000000
# 6 dep 7 | (1, 2) with p-value 0.000000
# 6 dep 7 | (1, 3) with p-value 0.000000
# 6 dep 7 | (1, 4) with p-value 0.000000
# 6 dep 7 | (1, 5) with p-value 0.000000
# 6 dep 7 | (2, 3) with p-value 0.000000
# 6 dep 7 | (2, 4) with p-value 0.000000
# 6 dep 7 | (2, 5) with p-value 0.000000
# 6 dep 7 | (3, 4) with p-value 0.000000
# 6 dep 7 | (3, 5) with p-value 0.000000
# 6 dep 7 | (4, 5) with p-value 0.000000
# Neighbors of 7 in (Z,X) are [2 6]
# Testing edges from 7 to 2
# 7 dep 2 | (0, 1) with p-value 0.000000
# 7 dep 2 | (0, 3) with p-value 0.000000
# 7 dep 2 | (0, 4) with p-value 0.000000
# 7 dep 2 | (0, 5) with p-value 0.000000
# 7 dep 2 | (0, 6) with p-value 0.000000
# 7 dep 2 | (1, 3) with p-value 0.000000
# 7 dep 2 | (1, 4) with p-value 0.000000
# 7 dep 2 | (1, 5) with p-value 0.000000
# 7 dep 2 | (1, 6) with p-value 0.000000
# 7 dep 2 | (3, 4) with p-value 0.000000
# 7 dep 2 | (3, 5) with p-value 0.000000
# 7 dep 2 | (3, 6) with p-value 0.000000
# 7 dep 2 | (4, 5) with p-value 0.000000
# 7 dep 2 | (4, 6) with p-value 0.000000
# 7 dep 2 | (5, 6) with p-value 0.000000
# Testing edges from 7 to 6
# 7 dep 6 | (0, 1) with p-value 0.000000
# 7 dep 6 | (0, 2) with p-value 0.000000
# 7 dep 6 | (0, 3) with p-value 0.000000
# 7 dep 6 | (0, 4) with p-value 0.000000
# 7 dep 6 | (0, 5) with p-value 0.000000
# 7 dep 6 | (1, 2) with p-value 0.000000
# 7 dep 6 | (1, 3) with p-value 0.000000
# 7 dep 6 | (1, 4) with p-value 0.000000
# 7 dep 6 | (1, 5) with p-value 0.000000
# 7 dep 6 | (2, 3) with p-value 0.000000
# 7 dep 6 | (2, 4) with p-value 0.000000
# 7 dep 6 | (2, 5) with p-value 0.000000
# 7 dep 6 | (3, 4) with p-value 0.000000
# 7 dep 6 | (3, 5) with p-value 0.000000
# 7 dep 6 | (4, 5) with p-value 0.000000
# Deleted edge from X2 to Z2
# Neighbors of 0 in (Z,X) are [1 5]
# Testing edges from 0 to 1
# 0 dep 1 | (2, 3, 4) with p-value 0.000000
# 0 dep 1 | (2, 3, 5) with p-value 0.000000
# 0 dep 1 | (2, 3, 6) with p-value 0.000000
# 0 dep 1 | (2, 3, 7) with p-value 0.000000
# 0 dep 1 | (2, 4, 5) with p-value 0.000000
# 0 dep 1 | (2, 4, 6) with p-value 0.000000
# 0 dep 1 | (2, 4, 7) with p-value 0.000000
# 0 dep 1 | (2, 5, 6) with p-value 0.000000
# 0 dep 1 | (2, 5, 7) with p-value 0.000000
# 0 dep 1 | (2, 6, 7) with p-value 0.000000
# 0 dep 1 | (3, 4, 5) with p-value 0.000000
# 0 dep 1 | (3, 4, 6) with p-value 0.000000
# 0 dep 1 | (3, 4, 7) with p-value 0.000000
# 0 dep 1 | (3, 5, 6) with p-value 0.000000
# 0 dep 1 | (3, 5, 7) with p-value 0.000000
# 0 dep 1 | (3, 6, 7) with p-value 0.000000
# 0 dep 1 | (4, 5, 6) with p-value 0.000000
# 0 dep 1 | (4, 5, 7) with p-value 0.000610
# 0 dep 1 | (4, 6, 7) with p-value 0.000000
# 0 dep 1 | (5, 6, 7) with p-value 0.000000
# Testing edges from 0 to 5
# 0 dep 5 | (1, 2, 3) with p-value 0.000000
# 0 dep 5 | (1, 2, 4) with p-value 0.000000
# 0 dep 5 | (1, 2, 6) with p-value 0.000000
# 0 dep 5 | (1, 2, 7) with p-value 0.000000
# 0 dep 5 | (1, 3, 4) with p-value 0.000000
# 0 dep 5 | (1, 3, 6) with p-value 0.000000
# 0 dep 5 | (1, 3, 7) with p-value 0.000000
# 0 dep 5 | (1, 4, 6) with p-value 0.000000
# 0 dep 5 | (1, 4, 7) with p-value 0.000000
# 0 dep 5 | (1, 6, 7) with p-value 0.000000
# 0 dep 5 | (2, 3, 4) with p-value 0.000000
# 0 dep 5 | (2, 3, 6) with p-value 0.000000
# 0 dep 5 | (2, 3, 7) with p-value 0.000000
# 0 dep 5 | (2, 4, 6) with p-value 0.000000
# 0 dep 5 | (2, 4, 7) with p-value 0.000000
# 0 dep 5 | (2, 6, 7) with p-value 0.000000
# 0 dep 5 | (3, 4, 6) with p-value 0.000000
# 0 dep 5 | (3, 4, 7) with p-value 0.000000
# 0 dep 5 | (3, 6, 7) with p-value 0.000000
# 0 dep 5 | (4, 6, 7) with p-value 0.000000
# Neighbors of 1 in (Z,X) are [0]
# Testing edges from 1 to 0
# 1 dep 0 | (2, 3, 4) with p-value 0.000000
# 1 dep 0 | (2, 3, 5) with p-value 0.000000
# 1 dep 0 | (2, 3, 6) with p-value 0.000000
# 1 dep 0 | (2, 3, 7) with p-value 0.000000
# 1 dep 0 | (2, 4, 5) with p-value 0.000000
# 1 dep 0 | (2, 4, 6) with p-value 0.000000
# 1 dep 0 | (2, 4, 7) with p-value 0.000000
# 1 dep 0 | (2, 5, 6) with p-value 0.000000
# 1 dep 0 | (2, 5, 7) with p-value 0.000000
# 1 dep 0 | (2, 6, 7) with p-value 0.000000
# 1 dep 0 | (3, 4, 5) with p-value 0.000000
# 1 dep 0 | (3, 4, 6) with p-value 0.000000
# 1 dep 0 | (3, 4, 7) with p-value 0.000000
# 1 dep 0 | (3, 5, 6) with p-value 0.000000
# 1 dep 0 | (3, 5, 7) with p-value 0.000000
# 1 dep 0 | (3, 6, 7) with p-value 0.000000
# 1 dep 0 | (4, 5, 6) with p-value 0.000000
# 1 dep 0 | (4, 5, 7) with p-value 0.000610
# 1 dep 0 | (4, 6, 7) with p-value 0.000000
# 1 dep 0 | (5, 6, 7) with p-value 0.000000
# Neighbors of 2 in (Z,X) are [7]
# Testing edges from 2 to 7
# 2 dep 7 | (0, 1, 3) with p-value 0.000000
# 2 dep 7 | (0, 1, 4) with p-value 0.000000
# 2 dep 7 | (0, 1, 5) with p-value 0.000000
# 2 dep 7 | (0, 1, 6) with p-value 0.000000
# 2 dep 7 | (0, 3, 4) with p-value 0.000000
# 2 dep 7 | (0, 3, 5) with p-value 0.000000
# 2 dep 7 | (0, 3, 6) with p-value 0.000000
# 2 dep 7 | (0, 4, 5) with p-value 0.000000
# 2 dep 7 | (0, 4, 6) with p-value 0.000000
# 2 dep 7 | (0, 5, 6) with p-value 0.000000
# 2 dep 7 | (1, 3, 4) with p-value 0.000000
# 2 dep 7 | (1, 3, 5) with p-value 0.000000
# 2 dep 7 | (1, 3, 6) with p-value 0.000000
# 2 dep 7 | (1, 4, 5) with p-value 0.000000
# 2 dep 7 | (1, 4, 6) with p-value 0.000000
# 2 dep 7 | (1, 5, 6) with p-value 0.000000
# 2 dep 7 | (3, 4, 5) with p-value 0.000000
# 2 dep 7 | (3, 4, 6) with p-value 0.000000
# 2 dep 7 | (3, 5, 6) with p-value 0.000000
# 2 dep 7 | (4, 5, 6) with p-value 0.000000
# Neighbors of 5 in (Z,X) are [0 6]
# Testing edges from 5 to 0
# 5 dep 0 | (1, 2, 3) with p-value 0.000000
# 5 dep 0 | (1, 2, 4) with p-value 0.000000
# 5 dep 0 | (1, 2, 6) with p-value 0.000000
# 5 dep 0 | (1, 2, 7) with p-value 0.000000
# 5 dep 0 | (1, 3, 4) with p-value 0.000000
# 5 dep 0 | (1, 3, 6) with p-value 0.000000
# 5 dep 0 | (1, 3, 7) with p-value 0.000000
# 5 dep 0 | (1, 4, 6) with p-value 0.000000
# 5 dep 0 | (1, 4, 7) with p-value 0.000000
# 5 dep 0 | (1, 6, 7) with p-value 0.000000
# 5 dep 0 | (2, 3, 4) with p-value 0.000000
# 5 dep 0 | (2, 3, 6) with p-value 0.000000
# 5 dep 0 | (2, 3, 7) with p-value 0.000000
# 5 dep 0 | (2, 4, 6) with p-value 0.000000
# 5 dep 0 | (2, 4, 7) with p-value 0.000000
# 5 dep 0 | (2, 6, 7) with p-value 0.000000
# 5 dep 0 | (3, 4, 6) with p-value 0.000000
# 5 dep 0 | (3, 4, 7) with p-value 0.000000
# 5 dep 0 | (3, 6, 7) with p-value 0.000000
# 5 dep 0 | (4, 6, 7) with p-value 0.000000
# Testing edges from 5 to 6
# 5 dep 6 | (0, 1, 2) with p-value 0.000000
# 5 dep 6 | (0, 1, 3) with p-value 0.000000
# 5 dep 6 | (0, 1, 4) with p-value 0.000000
# 5 dep 6 | (0, 1, 7) with p-value 0.000000
# 5 dep 6 | (0, 2, 3) with p-value 0.000000
# 5 dep 6 | (0, 2, 4) with p-value 0.000000
# 5 dep 6 | (0, 2, 7) with p-value 0.000000
# 5 dep 6 | (0, 3, 4) with p-value 0.000000
# 5 dep 6 | (0, 3, 7) with p-value 0.000001
# 5 dep 6 | (0, 4, 7) with p-value 0.000000
# 5 dep 6 | (1, 2, 3) with p-value 0.000000
# 5 dep 6 | (1, 2, 4) with p-value 0.000000
# 5 dep 6 | (1, 2, 7) with p-value 0.000000
# 5 dep 6 | (1, 3, 4) with p-value 0.000000
# 5 dep 6 | (1, 3, 7) with p-value 0.000000
# 5 dep 6 | (1, 4, 7) with p-value 0.000000
# 5 dep 6 | (2, 3, 4) with p-value 0.000000
# 5 ind 6 | (2, 3, 7) with p-value 0.826159
# 5 dep 6 | (2, 4, 7) with p-value 0.000000
# 5 dep 6 | (3, 4, 7) with p-value 0.000000
# Neighbors of 6 in (Z,X) are [5 7]
# Testing edges from 6 to 5
# 6 dep 5 | (0, 1, 2) with p-value 0.000000
# 6 dep 5 | (0, 1, 3) with p-value 0.000000
# 6 dep 5 | (0, 1, 4) with p-value 0.000000
# 6 dep 5 | (0, 1, 7) with p-value 0.000000
# 6 dep 5 | (0, 2, 3) with p-value 0.000000
# 6 dep 5 | (0, 2, 4) with p-value 0.000000
# 6 dep 5 | (0, 2, 7) with p-value 0.000000
# 6 dep 5 | (0, 3, 4) with p-value 0.000000
# 6 dep 5 | (0, 3, 7) with p-value 0.000001
# 6 dep 5 | (0, 4, 7) with p-value 0.000000
# 6 dep 5 | (1, 2, 3) with p-value 0.000000
# 6 dep 5 | (1, 2, 4) with p-value 0.000000
# 6 dep 5 | (1, 2, 7) with p-value 0.000000
# 6 dep 5 | (1, 3, 4) with p-value 0.000000
# 6 dep 5 | (1, 3, 7) with p-value 0.000000
# 6 dep 5 | (1, 4, 7) with p-value 0.000000
# 6 dep 5 | (2, 3, 4) with p-value 0.000000
# 6 ind 5 | (2, 3, 7) with p-value 0.826159
# 6 dep 5 | (2, 4, 7) with p-value 0.000000
# 6 dep 5 | (3, 4, 7) with p-value 0.000000
# Testing edges from 6 to 7
# 6 dep 7 | (0, 1, 2) with p-value 0.000000
# 6 dep 7 | (0, 1, 3) with p-value 0.000000
# 6 dep 7 | (0, 1, 4) with p-value 0.000000
# 6 dep 7 | (0, 1, 5) with p-value 0.000000
# 6 dep 7 | (0, 2, 3) with p-value 0.000000
# 6 dep 7 | (0, 2, 4) with p-value 0.000000
# 6 dep 7 | (0, 2, 5) with p-value 0.000000
# 6 dep 7 | (0, 3, 4) with p-value 0.000000
# 6 dep 7 | (0, 3, 5) with p-value 0.000000
# 6 dep 7 | (0, 4, 5) with p-value 0.000000
# 6 dep 7 | (1, 2, 3) with p-value 0.000000
# 6 dep 7 | (1, 2, 4) with p-value 0.000000
# 6 dep 7 | (1, 2, 5) with p-value 0.000000
# 6 dep 7 | (1, 3, 4) with p-value 0.000000
# 6 dep 7 | (1, 3, 5) with p-value 0.000000
# 6 dep 7 | (1, 4, 5) with p-value 0.000000
# 6 dep 7 | (2, 3, 4) with p-value 0.000000
# 6 dep 7 | (2, 3, 5) with p-value 0.000000
# 6 dep 7 | (2, 4, 5) with p-value 0.000000
# 6 dep 7 | (3, 4, 5) with p-value 0.000000
# Neighbors of 7 in (Z,X) are [2 6]
# Testing edges from 7 to 2
# 7 dep 2 | (0, 1, 3) with p-value 0.000000
# 7 dep 2 | (0, 1, 4) with p-value 0.000000
# 7 dep 2 | (0, 1, 5) with p-value 0.000000
# 7 dep 2 | (0, 1, 6) with p-value 0.000000
# 7 dep 2 | (0, 3, 4) with p-value 0.000000
# 7 dep 2 | (0, 3, 5) with p-value 0.000000
# 7 dep 2 | (0, 3, 6) with p-value 0.000000
# 7 dep 2 | (0, 4, 5) with p-value 0.000000
# 7 dep 2 | (0, 4, 6) with p-value 0.000000
# 7 dep 2 | (0, 5, 6) with p-value 0.000000
# 7 dep 2 | (1, 3, 4) with p-value 0.000000
# 7 dep 2 | (1, 3, 5) with p-value 0.000000
# 7 dep 2 | (1, 3, 6) with p-value 0.000000
# 7 dep 2 | (1, 4, 5) with p-value 0.000000
# 7 dep 2 | (1, 4, 6) with p-value 0.000000
# 7 dep 2 | (1, 5, 6) with p-value 0.000000
# 7 dep 2 | (3, 4, 5) with p-value 0.000000
# 7 dep 2 | (3, 4, 6) with p-value 0.000000
# 7 dep 2 | (3, 5, 6) with p-value 0.000000
# 7 dep 2 | (4, 5, 6) with p-value 0.000000
# Testing edges from 7 to 6
# 7 dep 6 | (0, 1, 2) with p-value 0.000000
# 7 dep 6 | (0, 1, 3) with p-value 0.000000
# 7 dep 6 | (0, 1, 4) with p-value 0.000000
# 7 dep 6 | (0, 1, 5) with p-value 0.000000
# 7 dep 6 | (0, 2, 3) with p-value 0.000000
# 7 dep 6 | (0, 2, 4) with p-value 0.000000
# 7 dep 6 | (0, 2, 5) with p-value 0.000000
# 7 dep 6 | (0, 3, 4) with p-value 0.000000
# 7 dep 6 | (0, 3, 5) with p-value 0.000000
# 7 dep 6 | (0, 4, 5) with p-value 0.000000
# 7 dep 6 | (1, 2, 3) with p-value 0.000000
# 7 dep 6 | (1, 2, 4) with p-value 0.000000
# 7 dep 6 | (1, 2, 5) with p-value 0.000000
# 7 dep 6 | (1, 3, 4) with p-value 0.000000
# 7 dep 6 | (1, 3, 5) with p-value 0.000000
# 7 dep 6 | (1, 4, 5) with p-value 0.000000
# 7 dep 6 | (2, 3, 4) with p-value 0.000000
# 7 dep 6 | (2, 3, 5) with p-value 0.000000
# 7 dep 6 | (2, 4, 5) with p-value 0.000000
# 7 dep 6 | (3, 4, 5) with p-value 0.000000
# Deleted edge from Z1 to Z2
# Neighbors of 0 in (Z,X) are [1 5]
# Testing edges from 0 to 1
# 0 dep 1 | (2, 3, 4, 5) with p-value 0.000000
# 0 dep 1 | (2, 3, 4, 6) with p-value 0.000000
# 0 dep 1 | (2, 3, 4, 7) with p-value 0.000000
# 0 dep 1 | (2, 3, 5, 6) with p-value 0.000000
# 0 dep 1 | (2, 3, 5, 7) with p-value 0.000000
# 0 dep 1 | (2, 3, 6, 7) with p-value 0.000000
# 0 dep 1 | (2, 4, 5, 6) with p-value 0.000000
# 0 dep 1 | (2, 4, 5, 7) with p-value 0.039118
# 0 dep 1 | (2, 4, 6, 7) with p-value 0.000000
# 0 dep 1 | (2, 5, 6, 7) with p-value 0.000000
# 0 dep 1 | (3, 4, 5, 6) with p-value 0.000000
# 0 dep 1 | (3, 4, 5, 7) with p-value 0.000000
# 0 dep 1 | (3, 4, 6, 7) with p-value 0.000000
# 0 dep 1 | (3, 5, 6, 7) with p-value 0.000000
# 0 dep 1 | (4, 5, 6, 7) with p-value 0.000000
# Testing edges from 0 to 5
# 0 dep 5 | (1, 2, 3, 4) with p-value 0.000000
# 0 dep 5 | (1, 2, 3, 6) with p-value 0.000000
# 0 dep 5 | (1, 2, 3, 7) with p-value 0.000000
# 0 dep 5 | (1, 2, 4, 6) with p-value 0.000000
# 0 dep 5 | (1, 2, 4, 7) with p-value 0.000000
# 0 dep 5 | (1, 2, 6, 7) with p-value 0.000000
# 0 dep 5 | (1, 3, 4, 6) with p-value 0.000000
# 0 dep 5 | (1, 3, 4, 7) with p-value 0.000000
# 0 dep 5 | (1, 3, 6, 7) with p-value 0.000000
# 0 dep 5 | (1, 4, 6, 7) with p-value 0.000000
# 0 dep 5 | (2, 3, 4, 6) with p-value 0.000000
# 0 dep 5 | (2, 3, 4, 7) with p-value 0.000000
# 0 dep 5 | (2, 3, 6, 7) with p-value 0.000000
# 0 dep 5 | (2, 4, 6, 7) with p-value 0.000000
# 0 dep 5 | (3, 4, 6, 7) with p-value 0.000000
# Neighbors of 1 in (Z,X) are [0]
# Testing edges from 1 to 0
# 1 dep 0 | (2, 3, 4, 5) with p-value 0.000000
# 1 dep 0 | (2, 3, 4, 6) with p-value 0.000000
# 1 dep 0 | (2, 3, 4, 7) with p-value 0.000000
# 1 dep 0 | (2, 3, 5, 6) with p-value 0.000000
# 1 dep 0 | (2, 3, 5, 7) with p-value 0.000000
# 1 dep 0 | (2, 3, 6, 7) with p-value 0.000000
# 1 dep 0 | (2, 4, 5, 6) with p-value 0.000000
# 1 dep 0 | (2, 4, 5, 7) with p-value 0.039118
# 1 dep 0 | (2, 4, 6, 7) with p-value 0.000000
# 1 dep 0 | (2, 5, 6, 7) with p-value 0.000000
# 1 dep 0 | (3, 4, 5, 6) with p-value 0.000000
# 1 dep 0 | (3, 4, 5, 7) with p-value 0.000000
# 1 dep 0 | (3, 4, 6, 7) with p-value 0.000000
# 1 dep 0 | (3, 5, 6, 7) with p-value 0.000000
# 1 dep 0 | (4, 5, 6, 7) with p-value 0.000000
# Neighbors of 2 in (Z,X) are [7]
# Testing edges from 2 to 7
# 2 dep 7 | (0, 1, 3, 4) with p-value 0.000000
# 2 dep 7 | (0, 1, 3, 5) with p-value 0.000000
# 2 dep 7 | (0, 1, 3, 6) with p-value 0.000000
# 2 dep 7 | (0, 1, 4, 5) with p-value 0.000000
# 2 dep 7 | (0, 1, 4, 6) with p-value 0.000000
# 2 dep 7 | (0, 1, 5, 6) with p-value 0.000000
# 2 dep 7 | (0, 3, 4, 5) with p-value 0.000000
# 2 dep 7 | (0, 3, 4, 6) with p-value 0.000000
# 2 dep 7 | (0, 3, 5, 6) with p-value 0.000000
# 2 dep 7 | (0, 4, 5, 6) with p-value 0.000000
# 2 dep 7 | (1, 3, 4, 5) with p-value 0.000000
# 2 dep 7 | (1, 3, 4, 6) with p-value 0.000000
# 2 dep 7 | (1, 3, 5, 6) with p-value 0.000000
# 2 dep 7 | (1, 4, 5, 6) with p-value 0.000000
# 2 dep 7 | (3, 4, 5, 6) with p-value 0.000000
# Neighbors of 5 in (Z,X) are [0]
# Testing edges from 5 to 0
# 5 dep 0 | (1, 2, 3, 4) with p-value 0.000000
# 5 dep 0 | (1, 2, 3, 6) with p-value 0.000000
# 5 dep 0 | (1, 2, 3, 7) with p-value 0.000000
# 5 dep 0 | (1, 2, 4, 6) with p-value 0.000000
# 5 dep 0 | (1, 2, 4, 7) with p-value 0.000000
# 5 dep 0 | (1, 2, 6, 7) with p-value 0.000000
# 5 dep 0 | (1, 3, 4, 6) with p-value 0.000000
# 5 dep 0 | (1, 3, 4, 7) with p-value 0.000000
# 5 dep 0 | (1, 3, 6, 7) with p-value 0.000000
# 5 dep 0 | (1, 4, 6, 7) with p-value 0.000000
# 5 dep 0 | (2, 3, 4, 6) with p-value 0.000000
# 5 dep 0 | (2, 3, 4, 7) with p-value 0.000000
# 5 dep 0 | (2, 3, 6, 7) with p-value 0.000000
# 5 dep 0 | (2, 4, 6, 7) with p-value 0.000000
# 5 dep 0 | (3, 4, 6, 7) with p-value 0.000000
# Neighbors of 6 in (Z,X) are [7]
# Testing edges from 6 to 7
# 6 dep 7 | (0, 1, 2, 3) with p-value 0.000000
# 6 dep 7 | (0, 1, 2, 4) with p-value 0.000000
# 6 dep 7 | (0, 1, 2, 5) with p-value 0.000000
# 6 dep 7 | (0, 1, 3, 4) with p-value 0.000000
# 6 dep 7 | (0, 1, 3, 5) with p-value 0.000000
# 6 dep 7 | (0, 1, 4, 5) with p-value 0.000000
# 6 dep 7 | (0, 2, 3, 4) with p-value 0.000000
# 6 dep 7 | (0, 2, 3, 5) with p-value 0.000000
# 6 dep 7 | (0, 2, 4, 5) with p-value 0.000000
# 6 dep 7 | (0, 3, 4, 5) with p-value 0.000000
# 6 dep 7 | (1, 2, 3, 4) with p-value 0.000000
# 6 dep 7 | (1, 2, 3, 5) with p-value 0.000000
# 6 dep 7 | (1, 2, 4, 5) with p-value 0.000000
# 6 dep 7 | (1, 3, 4, 5) with p-value 0.000000
# 6 dep 7 | (2, 3, 4, 5) with p-value 0.000000
# Neighbors of 7 in (Z,X) are [2 6]
# Testing edges from 7 to 2
# 7 dep 2 | (0, 1, 3, 4) with p-value 0.000000
# 7 dep 2 | (0, 1, 3, 5) with p-value 0.000000
# 7 dep 2 | (0, 1, 3, 6) with p-value 0.000000
# 7 dep 2 | (0, 1, 4, 5) with p-value 0.000000
# 7 dep 2 | (0, 1, 4, 6) with p-value 0.000000
# 7 dep 2 | (0, 1, 5, 6) with p-value 0.000000
# 7 dep 2 | (0, 3, 4, 5) with p-value 0.000000
# 7 dep 2 | (0, 3, 4, 6) with p-value 0.000000
# 7 dep 2 | (0, 3, 5, 6) with p-value 0.000000
# 7 dep 2 | (0, 4, 5, 6) with p-value 0.000000
# 7 dep 2 | (1, 3, 4, 5) with p-value 0.000000
# 7 dep 2 | (1, 3, 4, 6) with p-value 0.000000
# 7 dep 2 | (1, 3, 5, 6) with p-value 0.000000
# 7 dep 2 | (1, 4, 5, 6) with p-value 0.000000
# 7 dep 2 | (3, 4, 5, 6) with p-value 0.000000
# Testing edges from 7 to 6
# 7 dep 6 | (0, 1, 2, 3) with p-value 0.000000
# 7 dep 6 | (0, 1, 2, 4) with p-value 0.000000
# 7 dep 6 | (0, 1, 2, 5) with p-value 0.000000
# 7 dep 6 | (0, 1, 3, 4) with p-value 0.000000
# 7 dep 6 | (0, 1, 3, 5) with p-value 0.000000
# 7 dep 6 | (0, 1, 4, 5) with p-value 0.000000
# 7 dep 6 | (0, 2, 3, 4) with p-value 0.000000
# 7 dep 6 | (0, 2, 3, 5) with p-value 0.000000
# 7 dep 6 | (0, 2, 4, 5) with p-value 0.000000
# 7 dep 6 | (0, 3, 4, 5) with p-value 0.000000
# 7 dep 6 | (1, 2, 3, 4) with p-value 0.000000
# 7 dep 6 | (1, 2, 3, 5) with p-value 0.000000
# 7 dep 6 | (1, 2, 4, 5) with p-value 0.000000
# 7 dep 6 | (1, 3, 4, 5) with p-value 0.000000
# 7 dep 6 | (2, 3, 4, 5) with p-value 0.000000
# Neighbors of 0 in (Z,X) are [1 5]
# Testing edges from 0 to 1
# 0 dep 1 | (2, 3, 4, 5, 6) with p-value 0.000000
# 0 dep 1 | (2, 3, 4, 5, 7) with p-value 0.000000
# 0 dep 1 | (2, 3, 4, 6, 7) with p-value 0.000000
# 0 dep 1 | (2, 3, 5, 6, 7) with p-value 0.000000
# 0 dep 1 | (2, 4, 5, 6, 7) with p-value 0.000000
# 0 dep 1 | (3, 4, 5, 6, 7) with p-value 0.000000
# Testing edges from 0 to 5
# 0 dep 5 | (1, 2, 3, 4, 6) with p-value 0.000000
# 0 dep 5 | (1, 2, 3, 4, 7) with p-value 0.000000
# 0 dep 5 | (1, 2, 3, 6, 7) with p-value 0.000000
# 0 dep 5 | (1, 2, 4, 6, 7) with p-value 0.000000
# 0 dep 5 | (1, 3, 4, 6, 7) with p-value 0.000000
# 0 dep 5 | (2, 3, 4, 6, 7) with p-value 0.000000
# Neighbors of 1 in (Z,X) are [0]
# Testing edges from 1 to 0
# 1 dep 0 | (2, 3, 4, 5, 6) with p-value 0.000000
# 1 dep 0 | (2, 3, 4, 5, 7) with p-value 0.000000
# 1 dep 0 | (2, 3, 4, 6, 7) with p-value 0.000000
# 1 dep 0 | (2, 3, 5, 6, 7) with p-value 0.000000
# 1 dep 0 | (2, 4, 5, 6, 7) with p-value 0.000000
# 1 dep 0 | (3, 4, 5, 6, 7) with p-value 0.000000
# Neighbors of 2 in (Z,X) are [7]
# Testing edges from 2 to 7
# 2 dep 7 | (0, 1, 3, 4, 5) with p-value 0.000000
# 2 dep 7 | (0, 1, 3, 4, 6) with p-value 0.000000
# 2 dep 7 | (0, 1, 3, 5, 6) with p-value 0.000000
# 2 dep 7 | (0, 1, 4, 5, 6) with p-value 0.000000
# 2 dep 7 | (0, 3, 4, 5, 6) with p-value 0.000000
# 2 dep 7 | (1, 3, 4, 5, 6) with p-value 0.000000
# Neighbors of 5 in (Z,X) are [0]
# Testing edges from 5 to 0
# 5 dep 0 | (1, 2, 3, 4, 6) with p-value 0.000000
# 5 dep 0 | (1, 2, 3, 4, 7) with p-value 0.000000
# 5 dep 0 | (1, 2, 3, 6, 7) with p-value 0.000000
# 5 dep 0 | (1, 2, 4, 6, 7) with p-value 0.000000
# 5 dep 0 | (1, 3, 4, 6, 7) with p-value 0.000000
# 5 dep 0 | (2, 3, 4, 6, 7) with p-value 0.000000
# Neighbors of 6 in (Z,X) are [7]
# Testing edges from 6 to 7
# 6 dep 7 | (0, 1, 2, 3, 4) with p-value 0.000000
# 6 dep 7 | (0, 1, 2, 3, 5) with p-value 0.000000
# 6 dep 7 | (0, 1, 2, 4, 5) with p-value 0.000000
# 6 dep 7 | (0, 1, 3, 4, 5) with p-value 0.000000
# 6 dep 7 | (0, 2, 3, 4, 5) with p-value 0.000000
# 6 dep 7 | (1, 2, 3, 4, 5) with p-value 0.000000
# Depth=6, working on node 7: 100%|██████████| 6/6 [00:00<00:00, 782.15it/s]
# Neighbors of 7 in (Z,X) are [2 6]
# Testing edges from 7 to 2
# 7 dep 2 | (0, 1, 3, 4, 5) with p-value 0.000000
# 7 dep 2 | (0, 1, 3, 4, 6) with p-value 0.000000
# 7 dep 2 | (0, 1, 3, 5, 6) with p-value 0.000000
# 7 dep 2 | (0, 1, 4, 5, 6) with p-value 0.000000
# 7 dep 2 | (0, 3, 4, 5, 6) with p-value 0.000000
# 7 dep 2 | (1, 3, 4, 5, 6) with p-value 0.000000
# Testing edges from 7 to 6
# 7 dep 6 | (0, 1, 2, 3, 4) with p-value 0.000000
# 7 dep 6 | (0, 1, 2, 3, 5) with p-value 0.000000
# 7 dep 6 | (0, 1, 2, 4, 5) with p-value 0.000000
# 7 dep 6 | (0, 1, 3, 4, 5) with p-value 0.000000
# 7 dep 6 | (0, 2, 3, 4, 5) with p-value 0.000000
# 7 dep 6 | (1, 2, 3, 4, 5) with p-value 0.000000
# Neighbors of 0 in (Z,X) are [1 5]
# Testing edges from 0 to 1
# 0 dep 1 | (2, 3, 4, 5, 6, 7) with p-value 0.000000
# Testing edges from 0 to 5
# 0 dep 5 | (1, 2, 3, 4, 6, 7) with p-value 0.000000
# Neighbors of 1 in (Z,X) are [0]
# Testing edges from 1 to 0
# 1 dep 0 | (2, 3, 4, 5, 6, 7) with p-value 0.000000
# Neighbors of 2 in (Z,X) are [7]
# Testing edges from 2 to 7
# 2 dep 7 | (0, 1, 3, 4, 5, 6) with p-value 0.000000
# Neighbors of 5 in (Z,X) are [0]
# Testing edges from 5 to 0
# 5 dep 0 | (1, 2, 3, 4, 6, 7) with p-value 0.000000
# Neighbors of 6 in (Z,X) are [7]
# Testing edges from 6 to 7
# 6 dep 7 | (0, 1, 2, 3, 4, 5) with p-value 0.000000
# Neighbors of 7 in (Z,X) are [2 6]
# Testing edges from 7 to 2
# 7 dep 2 | (0, 1, 3, 4, 5, 6) with p-value 0.000000
# Testing edges from 7 to 6
# 7 dep 6 | (0, 1, 2, 3, 4, 5) with p-value 0.000000
#
# Inter phase between low cluster Z and parent Y
# Cluster node indices are [3 4 5 6 7]
# Local graph node indices are [3 4 5 6 7]
# Depth=0, working on node 4:  40%|████      | 2/5 [00:00<00:00, 1001.03it/s]
# Neighbors of 3 in (Z,Y) are [5 6 7]
# Testing edges from 3 to 5
# 3 dep 5 | () with p-value 0.000000
# Testing edges from 3 to 6
# 3 dep 6 | () with p-value 0.000000
# Testing edges from 3 to 7
# 3 dep 7 | () with p-value 0.000000
# Depth=1, working on node 4:  40%|████      | 2/5 [00:00<00:00, 250.17it/s]
# Neighbors of 4 in (Z,Y) are [5 6 7]
# Testing edges from 4 to 5
# 4 ind 5 | () with p-value 0.909283
# Testing edges from 4 to 6
# 4 dep 6 | () with p-value 0.000000
# Testing edges from 4 to 7
# 4 dep 7 | () with p-value 0.000000
# Neighbors of 5 in (Z,Y) are [3 4]
# Testing edges from 5 to 3
# 5 dep 3 | () with p-value 0.000000
# Testing edges from 5 to 4
# 5 ind 4 | () with p-value 0.909283
# Neighbors of 6 in (Z,Y) are [3 4 7]
# Testing edges from 6 to 3
# 6 dep 3 | () with p-value 0.000000
# Testing edges from 6 to 4
# 6 dep 4 | () with p-value 0.000000
# Testing edges from 6 to 7
# 6 dep 7 | () with p-value 0.000000
# Neighbors of 7 in (Z,Y) are [3 4 6]
# Testing edges from 7 to 3
# 7 dep 3 | () with p-value 0.000000
# Testing edges from 7 to 4
# 7 dep 4 | () with p-value 0.000000
# Testing edges from 7 to 6
# 7 dep 6 | () with p-value 0.000000
# Deleted edge from Y2 to Z1
# Neighbors of 3 in (Z,Y) are [5 6 7]
# Testing edges from 3 to 5
# 3 dep 5 | (0,) with p-value 0.000000
# 3 dep 5 | (1,) with p-value 0.000000
# 3 dep 5 | (2,) with p-value 0.000000
# 3 dep 5 | (4,) with p-value 0.000000
# 3 dep 5 | (6,) with p-value 0.000000
# 3 dep 5 | (7,) with p-value 0.000000
# Testing edges from 3 to 6
# 3 dep 6 | (0,) with p-value 0.000000
# 3 dep 6 | (1,) with p-value 0.000000
# 3 dep 6 | (2,) with p-value 0.000000
# 3 dep 6 | (4,) with p-value 0.000000
# 3 dep 6 | (5,) with p-value 0.000000
# 3 dep 6 | (7,) with p-value 0.000000
# Testing edges from 3 to 7
# 3 dep 7 | (0,) with p-value 0.000000
# 3 dep 7 | (1,) with p-value 0.000000
# 3 dep 7 | (2,) with p-value 0.000000
# 3 dep 7 | (4,) with p-value 0.000000
# 3 dep 7 | (5,) with p-value 0.000000
# 3 ind 7 | (6,) with p-value 0.948457
# Depth=3, working on node 7: 100%|██████████| 5/5 [00:00<00:00, 199.69it/s]
# Neighbors of 4 in (Z,Y) are [6 7]
# Testing edges from 4 to 6
# 4 dep 6 | (0,) with p-value 0.000000
# 4 dep 6 | (1,) with p-value 0.000000
# 4 dep 6 | (2,) with p-value 0.000000
# 4 dep 6 | (3,) with p-value 0.000000
# 4 dep 6 | (5,) with p-value 0.000000
# 4 dep 6 | (7,) with p-value 0.000000
# Testing edges from 4 to 7
# 4 dep 7 | (0,) with p-value 0.000000
# 4 dep 7 | (1,) with p-value 0.000000
# 4 dep 7 | (2,) with p-value 0.000000
# 4 dep 7 | (3,) with p-value 0.000000
# 4 dep 7 | (5,) with p-value 0.000000
# 4 ind 7 | (6,) with p-value 0.688343
# Neighbors of 5 in (Z,Y) are [3]
# Testing edges from 5 to 3
# 5 dep 3 | (0,) with p-value 0.000000
# 5 dep 3 | (1,) with p-value 0.000000
# 5 dep 3 | (2,) with p-value 0.000000
# 5 dep 3 | (4,) with p-value 0.000000
# 5 dep 3 | (6,) with p-value 0.000000
# 5 dep 3 | (7,) with p-value 0.000000
# Neighbors of 6 in (Z,Y) are [3 4 7]
# Testing edges from 6 to 3
# 6 dep 3 | (0,) with p-value 0.000000
# 6 dep 3 | (1,) with p-value 0.000000
# 6 dep 3 | (2,) with p-value 0.000000
# 6 dep 3 | (4,) with p-value 0.000000
# 6 dep 3 | (5,) with p-value 0.000000
# 6 dep 3 | (7,) with p-value 0.000000
# Testing edges from 6 to 4
# 6 dep 4 | (0,) with p-value 0.000000
# 6 dep 4 | (1,) with p-value 0.000000
# 6 dep 4 | (2,) with p-value 0.000000
# 6 dep 4 | (3,) with p-value 0.000000
# 6 dep 4 | (5,) with p-value 0.000000
# 6 dep 4 | (7,) with p-value 0.000000
# Testing edges from 6 to 7
# 6 dep 7 | (0,) with p-value 0.000000
# 6 dep 7 | (1,) with p-value 0.000000
# 6 dep 7 | (2,) with p-value 0.000000
# 6 dep 7 | (3,) with p-value 0.000000
# 6 dep 7 | (4,) with p-value 0.000000
# 6 dep 7 | (5,) with p-value 0.000000
# Neighbors of 7 in (Z,Y) are [3 4 6]
# Testing edges from 7 to 3
# 7 dep 3 | (0,) with p-value 0.000000
# 7 dep 3 | (1,) with p-value 0.000000
# 7 dep 3 | (2,) with p-value 0.000000
# 7 dep 3 | (4,) with p-value 0.000000
# 7 dep 3 | (5,) with p-value 0.000000
# 7 ind 3 | (6,) with p-value 0.948457
# Testing edges from 7 to 4
# 7 dep 4 | (0,) with p-value 0.000000
# 7 dep 4 | (1,) with p-value 0.000000
# 7 dep 4 | (2,) with p-value 0.000000
# 7 dep 4 | (3,) with p-value 0.000000
# 7 dep 4 | (5,) with p-value 0.000000
# 7 ind 4 | (6,) with p-value 0.688343
# Testing edges from 7 to 6
# 7 dep 6 | (0,) with p-value 0.000000
# 7 dep 6 | (1,) with p-value 0.000000
# 7 dep 6 | (2,) with p-value 0.000000
# 7 dep 6 | (3,) with p-value 0.000000
# 7 dep 6 | (4,) with p-value 0.000000
# 7 dep 6 | (5,) with p-value 0.000000
# Deleted edge from Z3 to Y2
# Deleted edge from Y1 to Z3
# Neighbors of 3 in (Z,Y) are [5 6]
# Testing edges from 3 to 5
# 3 dep 5 | (0, 1) with p-value 0.000000
# 3 dep 5 | (0, 2) with p-value 0.000000
# 3 dep 5 | (0, 4) with p-value 0.000000
# 3 dep 5 | (0, 6) with p-value 0.000000
# 3 dep 5 | (0, 7) with p-value 0.000000
# 3 dep 5 | (1, 2) with p-value 0.000000
# 3 dep 5 | (1, 4) with p-value 0.000000
# 3 dep 5 | (1, 6) with p-value 0.000000
# 3 dep 5 | (1, 7) with p-value 0.000000
# 3 dep 5 | (2, 4) with p-value 0.000000
# 3 dep 5 | (2, 6) with p-value 0.000000
# 3 dep 5 | (2, 7) with p-value 0.000000
# 3 dep 5 | (4, 6) with p-value 0.000000
# 3 dep 5 | (4, 7) with p-value 0.000000
# 3 dep 5 | (6, 7) with p-value 0.000000
# Testing edges from 3 to 6
# 3 dep 6 | (0, 1) with p-value 0.000000
# 3 dep 6 | (0, 2) with p-value 0.000000
# 3 dep 6 | (0, 4) with p-value 0.000000
# 3 dep 6 | (0, 5) with p-value 0.000000
# 3 dep 6 | (0, 7) with p-value 0.000000
# 3 dep 6 | (1, 2) with p-value 0.000000
# 3 dep 6 | (1, 4) with p-value 0.000000
# 3 dep 6 | (1, 5) with p-value 0.000000
# 3 dep 6 | (1, 7) with p-value 0.000000
# 3 dep 6 | (2, 4) with p-value 0.000000
# 3 dep 6 | (2, 5) with p-value 0.000000
# 3 dep 6 | (2, 7) with p-value 0.000000
# 3 dep 6 | (4, 5) with p-value 0.000000
# 3 dep 6 | (4, 7) with p-value 0.000000
# 3 dep 6 | (5, 7) with p-value 0.000000
# Neighbors of 4 in (Z,Y) are [6]
# Testing edges from 4 to 6
# 4 dep 6 | (0, 1) with p-value 0.000000
# 4 dep 6 | (0, 2) with p-value 0.000000
# 4 dep 6 | (0, 3) with p-value 0.000000
# 4 dep 6 | (0, 5) with p-value 0.000000
# 4 dep 6 | (0, 7) with p-value 0.000000
# 4 dep 6 | (1, 2) with p-value 0.000000
# 4 dep 6 | (1, 3) with p-value 0.000000
# 4 dep 6 | (1, 5) with p-value 0.000000
# 4 dep 6 | (1, 7) with p-value 0.000000
# 4 dep 6 | (2, 3) with p-value 0.000000
# 4 dep 6 | (2, 5) with p-value 0.000000
# 4 dep 6 | (2, 7) with p-value 0.000118
# 4 dep 6 | (3, 5) with p-value 0.000000
# 4 dep 6 | (3, 7) with p-value 0.000000
# 4 dep 6 | (5, 7) with p-value 0.000000
# Neighbors of 5 in (Z,Y) are [3]
# Testing edges from 5 to 3
# 5 dep 3 | (0, 1) with p-value 0.000000
# 5 dep 3 | (0, 2) with p-value 0.000000
# 5 dep 3 | (0, 4) with p-value 0.000000
# 5 dep 3 | (0, 6) with p-value 0.000000
# 5 dep 3 | (0, 7) with p-value 0.000000
# 5 dep 3 | (1, 2) with p-value 0.000000
# 5 dep 3 | (1, 4) with p-value 0.000000
# 5 dep 3 | (1, 6) with p-value 0.000000
# 5 dep 3 | (1, 7) with p-value 0.000000
# 5 dep 3 | (2, 4) with p-value 0.000000
# 5 dep 3 | (2, 6) with p-value 0.000000
# 5 dep 3 | (2, 7) with p-value 0.000000
# 5 dep 3 | (4, 6) with p-value 0.000000
# 5 dep 3 | (4, 7) with p-value 0.000000
# 5 dep 3 | (6, 7) with p-value 0.000000
# Neighbors of 6 in (Z,Y) are [3 4 7]
# Testing edges from 6 to 3
# 6 dep 3 | (0, 1) with p-value 0.000000
# 6 dep 3 | (0, 2) with p-value 0.000000
# 6 dep 3 | (0, 4) with p-value 0.000000
# 6 dep 3 | (0, 5) with p-value 0.000000
# 6 dep 3 | (0, 7) with p-value 0.000000
# 6 dep 3 | (1, 2) with p-value 0.000000
# 6 dep 3 | (1, 4) with p-value 0.000000
# 6 dep 3 | (1, 5) with p-value 0.000000
# 6 dep 3 | (1, 7) with p-value 0.000000
# 6 dep 3 | (2, 4) with p-value 0.000000
# 6 dep 3 | (2, 5) with p-value 0.000000
# 6 dep 3 | (2, 7) with p-value 0.000000
# 6 dep 3 | (4, 5) with p-value 0.000000
# 6 dep 3 | (4, 7) with p-value 0.000000
# 6 dep 3 | (5, 7) with p-value 0.000000
# Testing edges from 6 to 4
# 6 dep 4 | (0, 1) with p-value 0.000000
# 6 dep 4 | (0, 2) with p-value 0.000000
# 6 dep 4 | (0, 3) with p-value 0.000000
# 6 dep 4 | (0, 5) with p-value 0.000000
# 6 dep 4 | (0, 7) with p-value 0.000000
# 6 dep 4 | (1, 2) with p-value 0.000000
# 6 dep 4 | (1, 3) with p-value 0.000000
# 6 dep 4 | (1, 5) with p-value 0.000000
# 6 dep 4 | (1, 7) with p-value 0.000000
# 6 dep 4 | (2, 3) with p-value 0.000000
# 6 dep 4 | (2, 5) with p-value 0.000000
# 6 dep 4 | (2, 7) with p-value 0.000118
# 6 dep 4 | (3, 5) with p-value 0.000000
# 6 dep 4 | (3, 7) with p-value 0.000000
# 6 dep 4 | (5, 7) with p-value 0.000000
# Testing edges from 6 to 7
# 6 dep 7 | (0, 1) with p-value 0.000000
# 6 dep 7 | (0, 2) with p-value 0.000000
# 6 dep 7 | (0, 3) with p-value 0.000000
# 6 dep 7 | (0, 4) with p-value 0.000000
# 6 dep 7 | (0, 5) with p-value 0.000000
# 6 dep 7 | (1, 2) with p-value 0.000000
# 6 dep 7 | (1, 3) with p-value 0.000000
# 6 dep 7 | (1, 4) with p-value 0.000000
# 6 dep 7 | (1, 5) with p-value 0.000000
# 6 dep 7 | (2, 3) with p-value 0.000000
# 6 dep 7 | (2, 4) with p-value 0.000000
# 6 dep 7 | (2, 5) with p-value 0.000000
# 6 dep 7 | (3, 4) with p-value 0.000000
# 6 dep 7 | (3, 5) with p-value 0.000000
# 6 dep 7 | (4, 5) with p-value 0.000000
# Neighbors of 7 in (Z,Y) are [6]
# Testing edges from 7 to 6
# 7 dep 6 | (0, 1) with p-value 0.000000
# 7 dep 6 | (0, 2) with p-value 0.000000
# 7 dep 6 | (0, 3) with p-value 0.000000
# 7 dep 6 | (0, 4) with p-value 0.000000
# 7 dep 6 | (0, 5) with p-value 0.000000
# 7 dep 6 | (1, 2) with p-value 0.000000
# 7 dep 6 | (1, 3) with p-value 0.000000
# 7 dep 6 | (1, 4) with p-value 0.000000
# 7 dep 6 | (1, 5) with p-value 0.000000
# 7 dep 6 | (2, 3) with p-value 0.000000
# 7 dep 6 | (2, 4) with p-value 0.000000
# 7 dep 6 | (2, 5) with p-value 0.000000
# 7 dep 6 | (3, 4) with p-value 0.000000
# 7 dep 6 | (3, 5) with p-value 0.000000
# 7 dep 6 | (4, 5) with p-value 0.000000
# Neighbors of 3 in (Z,Y) are [5 6]
# Testing edges from 3 to 5
# 3 dep 5 | (0, 1, 2) with p-value 0.000000
# 3 dep 5 | (0, 1, 4) with p-value 0.000000
# 3 dep 5 | (0, 1, 6) with p-value 0.000000
# 3 dep 5 | (0, 1, 7) with p-value 0.000000
# 3 dep 5 | (0, 2, 4) with p-value 0.000000
# 3 dep 5 | (0, 2, 6) with p-value 0.000000
# 3 dep 5 | (0, 2, 7) with p-value 0.000000
# 3 dep 5 | (0, 4, 6) with p-value 0.000000
# 3 dep 5 | (0, 4, 7) with p-value 0.000000
# 3 dep 5 | (0, 6, 7) with p-value 0.000000
# 3 dep 5 | (1, 2, 4) with p-value 0.000000
# 3 dep 5 | (1, 2, 6) with p-value 0.000000
# 3 dep 5 | (1, 2, 7) with p-value 0.000000
# 3 dep 5 | (1, 4, 6) with p-value 0.000000
# 3 dep 5 | (1, 4, 7) with p-value 0.000000
# 3 dep 5 | (1, 6, 7) with p-value 0.000000
# 3 dep 5 | (2, 4, 6) with p-value 0.000000
# 3 dep 5 | (2, 4, 7) with p-value 0.000000
# 3 dep 5 | (2, 6, 7) with p-value 0.000000
# 3 dep 5 | (4, 6, 7) with p-value 0.000000
# Testing edges from 3 to 6
# 3 dep 6 | (0, 1, 2) with p-value 0.000000
# 3 dep 6 | (0, 1, 4) with p-value 0.000000
# 3 dep 6 | (0, 1, 5) with p-value 0.000000
# 3 dep 6 | (0, 1, 7) with p-value 0.000000
# 3 dep 6 | (0, 2, 4) with p-value 0.000000
# 3 dep 6 | (0, 2, 5) with p-value 0.000000
# 3 dep 6 | (0, 2, 7) with p-value 0.000000
# 3 dep 6 | (0, 4, 5) with p-value 0.000000
# 3 dep 6 | (0, 4, 7) with p-value 0.000000
# 3 dep 6 | (0, 5, 7) with p-value 0.003140
# 3 dep 6 | (1, 2, 4) with p-value 0.000000
# 3 dep 6 | (1, 2, 5) with p-value 0.000000
# 3 dep 6 | (1, 2, 7) with p-value 0.000000
# 3 dep 6 | (1, 4, 5) with p-value 0.000000
# 3 dep 6 | (1, 4, 7) with p-value 0.000000
# 3 dep 6 | (1, 5, 7) with p-value 0.000000
# 3 dep 6 | (2, 4, 5) with p-value 0.000000
# 3 dep 6 | (2, 4, 7) with p-value 0.000000
# 3 dep 6 | (2, 5, 7) with p-value 0.000000
# 3 dep 6 | (4, 5, 7) with p-value 0.000000
# Neighbors of 4 in (Z,Y) are [6]
# Testing edges from 4 to 6
# 4 dep 6 | (0, 1, 2) with p-value 0.000000
# 4 dep 6 | (0, 1, 3) with p-value 0.000000
# 4 dep 6 | (0, 1, 5) with p-value 0.000000
# 4 dep 6 | (0, 1, 7) with p-value 0.000000
# 4 dep 6 | (0, 2, 3) with p-value 0.000000
# 4 dep 6 | (0, 2, 5) with p-value 0.000000
# 4 dep 6 | (0, 2, 7) with p-value 0.000142
# 4 dep 6 | (0, 3, 5) with p-value 0.000000
# 4 dep 6 | (0, 3, 7) with p-value 0.000000
# 4 dep 6 | (0, 5, 7) with p-value 0.000000
# 4 dep 6 | (1, 2, 3) with p-value 0.000000
# 4 dep 6 | (1, 2, 5) with p-value 0.000000
# 4 dep 6 | (1, 2, 7) with p-value 0.000061
# 4 dep 6 | (1, 3, 5) with p-value 0.000000
# 4 dep 6 | (1, 3, 7) with p-value 0.000000
# 4 dep 6 | (1, 5, 7) with p-value 0.000000
# 4 dep 6 | (2, 3, 5) with p-value 0.000000
# 4 dep 6 | (2, 3, 7) with p-value 0.000000
# 4 dep 6 | (2, 5, 7) with p-value 0.000000
# 4 dep 6 | (3, 5, 7) with p-value 0.000000
# Neighbors of 5 in (Z,Y) are [3]
# Testing edges from 5 to 3
# 5 dep 3 | (0, 1, 2) with p-value 0.000000
# 5 dep 3 | (0, 1, 4) with p-value 0.000000
# 5 dep 3 | (0, 1, 6) with p-value 0.000000
# 5 dep 3 | (0, 1, 7) with p-value 0.000000
# 5 dep 3 | (0, 2, 4) with p-value 0.000000
# 5 dep 3 | (0, 2, 6) with p-value 0.000000
# 5 dep 3 | (0, 2, 7) with p-value 0.000000
# 5 dep 3 | (0, 4, 6) with p-value 0.000000
# 5 dep 3 | (0, 4, 7) with p-value 0.000000
# 5 dep 3 | (0, 6, 7) with p-value 0.000000
# 5 dep 3 | (1, 2, 4) with p-value 0.000000
# 5 dep 3 | (1, 2, 6) with p-value 0.000000
# 5 dep 3 | (1, 2, 7) with p-value 0.000000
# 5 dep 3 | (1, 4, 6) with p-value 0.000000
# 5 dep 3 | (1, 4, 7) with p-value 0.000000
# 5 dep 3 | (1, 6, 7) with p-value 0.000000
# 5 dep 3 | (2, 4, 6) with p-value 0.000000
# 5 dep 3 | (2, 4, 7) with p-value 0.000000
# 5 dep 3 | (2, 6, 7) with p-value 0.000000
# 5 dep 3 | (4, 6, 7) with p-value 0.000000
# Neighbors of 6 in (Z,Y) are [3 4 7]
# Testing edges from 6 to 3
# 6 dep 3 | (0, 1, 2) with p-value 0.000000
# 6 dep 3 | (0, 1, 4) with p-value 0.000000
# 6 dep 3 | (0, 1, 5) with p-value 0.000000
# 6 dep 3 | (0, 1, 7) with p-value 0.000000
# 6 dep 3 | (0, 2, 4) with p-value 0.000000
# 6 dep 3 | (0, 2, 5) with p-value 0.000000
# 6 dep 3 | (0, 2, 7) with p-value 0.000000
# 6 dep 3 | (0, 4, 5) with p-value 0.000000
# 6 dep 3 | (0, 4, 7) with p-value 0.000000
# 6 dep 3 | (0, 5, 7) with p-value 0.003140
# 6 dep 3 | (1, 2, 4) with p-value 0.000000
# 6 dep 3 | (1, 2, 5) with p-value 0.000000
# 6 dep 3 | (1, 2, 7) with p-value 0.000000
# 6 dep 3 | (1, 4, 5) with p-value 0.000000
# 6 dep 3 | (1, 4, 7) with p-value 0.000000
# 6 dep 3 | (1, 5, 7) with p-value 0.000000
# 6 dep 3 | (2, 4, 5) with p-value 0.000000
# 6 dep 3 | (2, 4, 7) with p-value 0.000000
# 6 dep 3 | (2, 5, 7) with p-value 0.000000
# 6 dep 3 | (4, 5, 7) with p-value 0.000000
# Testing edges from 6 to 4
# 6 dep 4 | (0, 1, 2) with p-value 0.000000
# 6 dep 4 | (0, 1, 3) with p-value 0.000000
# 6 dep 4 | (0, 1, 5) with p-value 0.000000
# 6 dep 4 | (0, 1, 7) with p-value 0.000000
# 6 dep 4 | (0, 2, 3) with p-value 0.000000
# 6 dep 4 | (0, 2, 5) with p-value 0.000000
# 6 dep 4 | (0, 2, 7) with p-value 0.000142
# 6 dep 4 | (0, 3, 5) with p-value 0.000000
# 6 dep 4 | (0, 3, 7) with p-value 0.000000
# 6 dep 4 | (0, 5, 7) with p-value 0.000000
# 6 dep 4 | (1, 2, 3) with p-value 0.000000
# 6 dep 4 | (1, 2, 5) with p-value 0.000000
# 6 dep 4 | (1, 2, 7) with p-value 0.000061
# 6 dep 4 | (1, 3, 5) with p-value 0.000000
# 6 dep 4 | (1, 3, 7) with p-value 0.000000
# 6 dep 4 | (1, 5, 7) with p-value 0.000000
# 6 dep 4 | (2, 3, 5) with p-value 0.000000
# 6 dep 4 | (2, 3, 7) with p-value 0.000000
# 6 dep 4 | (2, 5, 7) with p-value 0.000000
# 6 dep 4 | (3, 5, 7) with p-value 0.000000
# Testing edges from 6 to 7
# 6 dep 7 | (0, 1, 2) with p-value 0.000000
# 6 dep 7 | (0, 1, 3) with p-value 0.000000
# 6 dep 7 | (0, 1, 4) with p-value 0.000000
# 6 dep 7 | (0, 1, 5) with p-value 0.000000
# 6 dep 7 | (0, 2, 3) with p-value 0.000000
# 6 dep 7 | (0, 2, 4) with p-value 0.000000
# 6 dep 7 | (0, 2, 5) with p-value 0.000000
# 6 dep 7 | (0, 3, 4) with p-value 0.000000
# 6 dep 7 | (0, 3, 5) with p-value 0.000000
# 6 dep 7 | (0, 4, 5) with p-value 0.000000
# 6 dep 7 | (1, 2, 3) with p-value 0.000000
# 6 dep 7 | (1, 2, 4) with p-value 0.000000
# 6 dep 7 | (1, 2, 5) with p-value 0.000000
# 6 dep 7 | (1, 3, 4) with p-value 0.000000
# 6 dep 7 | (1, 3, 5) with p-value 0.000000
# 6 dep 7 | (1, 4, 5) with p-value 0.000000
# 6 dep 7 | (2, 3, 4) with p-value 0.000000
# 6 dep 7 | (2, 3, 5) with p-value 0.000000
# 6 dep 7 | (2, 4, 5) with p-value 0.000000
# 6 dep 7 | (3, 4, 5) with p-value 0.000000
# Neighbors of 7 in (Z,Y) are [6]
# Testing edges from 7 to 6
# 7 dep 6 | (0, 1, 2) with p-value 0.000000
# 7 dep 6 | (0, 1, 3) with p-value 0.000000
# 7 dep 6 | (0, 1, 4) with p-value 0.000000
# 7 dep 6 | (0, 1, 5) with p-value 0.000000
# 7 dep 6 | (0, 2, 3) with p-value 0.000000
# 7 dep 6 | (0, 2, 4) with p-value 0.000000
# 7 dep 6 | (0, 2, 5) with p-value 0.000000
# 7 dep 6 | (0, 3, 4) with p-value 0.000000
# 7 dep 6 | (0, 3, 5) with p-value 0.000000
# 7 dep 6 | (0, 4, 5) with p-value 0.000000
# 7 dep 6 | (1, 2, 3) with p-value 0.000000
# 7 dep 6 | (1, 2, 4) with p-value 0.000000
# 7 dep 6 | (1, 2, 5) with p-value 0.000000
# 7 dep 6 | (1, 3, 4) with p-value 0.000000
# 7 dep 6 | (1, 3, 5) with p-value 0.000000
# 7 dep 6 | (1, 4, 5) with p-value 0.000000
# 7 dep 6 | (2, 3, 4) with p-value 0.000000
# 7 dep 6 | (2, 3, 5) with p-value 0.000000
# 7 dep 6 | (2, 4, 5) with p-value 0.000000
# 7 dep 6 | (3, 4, 5) with p-value 0.000000
#
# Intra phase in cluster Z
# Cluster node indices are [5 6 7]
# Local graph node indices are [5 6 7]
# Depth=2, working on node 7: 100%|██████████| 3/3 [00:00<00:00, 746.76it/s]
# Neighbors of 5 in Z are []
# Neighbors of 6 in Z are [7]
# Testing edges from 6 to 7
# 6 dep 7 | () with p-value 0.000000
# Neighbors of 7 in Z are [6]
# Testing edges from 7 to 6
# 7 dep 6 | () with p-value 0.000000
# Neighbors of 5 in Z are []
# Neighbors of 6 in Z are [7]
# Testing edges from 6 to 7
# 6 dep 7 | (0,) with p-value 0.000000
# 6 dep 7 | (1,) with p-value 0.000000
# 6 dep 7 | (2,) with p-value 0.000000
# 6 dep 7 | (3,) with p-value 0.000000
# 6 dep 7 | (4,) with p-value 0.000000
# 6 dep 7 | (5,) with p-value 0.000000
# Neighbors of 7 in Z are [6]
# Testing edges from 7 to 6
# 7 dep 6 | (0,) with p-value 0.000000
# 7 dep 6 | (1,) with p-value 0.000000
# 7 dep 6 | (2,) with p-value 0.000000
# 7 dep 6 | (3,) with p-value 0.000000
# 7 dep 6 | (4,) with p-value 0.000000
# 7 dep 6 | (5,) with p-value 0.000000
# Neighbors of 5 in Z are []
# Neighbors of 6 in Z are [7]
# Testing edges from 6 to 7
# 6 dep 7 | (0, 1) with p-value 0.000000
# 6 dep 7 | (0, 2) with p-value 0.000000
# 6 dep 7 | (0, 3) with p-value 0.000000
# 6 dep 7 | (0, 4) with p-value 0.000000
# 6 dep 7 | (0, 5) with p-value 0.000000
# 6 dep 7 | (1, 2) with p-value 0.000000
# 6 dep 7 | (1, 3) with p-value 0.000000
# 6 dep 7 | (1, 4) with p-value 0.000000
# 6 dep 7 | (1, 5) with p-value 0.000000
# 6 dep 7 | (2, 3) with p-value 0.000000
# 6 dep 7 | (2, 4) with p-value 0.000000
# 6 dep 7 | (2, 5) with p-value 0.000000
# 6 dep 7 | (3, 4) with p-value 0.000000
# 6 dep 7 | (3, 5) with p-value 0.000000
# 6 dep 7 | (4, 5) with p-value 0.000000
# Neighbors of 7 in Z are [6]
# Testing edges from 7 to 6
# 7 dep 6 | (0, 1) with p-value 0.000000
# 7 dep 6 | (0, 2) with p-value 0.000000
# 7 dep 6 | (0, 3) with p-value 0.000000
# 7 dep 6 | (0, 4) with p-value 0.000000
# 7 dep 6 | (0, 5) with p-value 0.000000
# 7 dep 6 | (1, 2) with p-value 0.000000
# 7 dep 6 | (1, 3) with p-value 0.000000
# 7 dep 6 | (1, 4) with p-value 0.000000
# 7 dep 6 | (1, 5) with p-value 0.000000
# 7 dep 6 | (2, 3) with p-value 0.000000
# 7 dep 6 | (2, 4) with p-value 0.000000
# 7 dep 6 | (2, 5) with p-value 0.000000
# 7 dep 6 | (3, 4) with p-value 0.000000
# 7 dep 6 | (3, 5) with p-value 0.000000
# 7 dep 6 | (4, 5) with p-value 0.000000
# Applying edge orientation rules
# Duration of algorithm was 0.29451799392700195sec

# %%
result_cdag.draw_pydot_graph()

# %%
# comparison to pc from causallearn
from causallearn.search.ConstraintBased.PC import pc
causallearn_cg = pc(data)
causallearn_cg.node_names = nodes
causallearn_cg.draw_pydot_graph(labels = nodes)
# Out:
# Depth=4, working on node 7: 100%|██████████| 8/8 [00:00<00:00, 889.50it/s]

# %%
causallearn_cg.node_names
# Out:
# ['X1', 'X2', 'X3', 'Y1', 'Y2', 'Z1', 'Z2', 'Z3']

# %%
draw_graph(nodes, edges)
# Out:
# INFO: oriented edge: (X1,X2)
# INFO: removed edge: (X1,X3)
# INFO: removed edge: (X1,Y1)
# INFO: removed edge: (X1,Y2)
# INFO: oriented edge: (X1,Z1)
# INFO: removed edge: (X1,Z2)
# INFO: removed edge: (X1,Z3)
# INFO: removed edge: (X2,X3)
# INFO: removed edge: (X2,Y1)
# INFO: removed edge: (X2,Y2)
# INFO: removed edge: (X2,Z1)
# INFO: oriented edge: (X2,Z2)
# INFO: removed edge: (X2,Z3)
# INFO: removed edge: (X3,Y1)
# INFO: removed edge: (X3,Y2)
# INFO: removed edge: (X3,Z1)
# INFO: removed edge: (X3,Z2)
# INFO: oriented edge: (X3,Z3)
# INFO: removed edge: (Y1,Y2)
# INFO: oriented edge: (Y1,Z1)
# INFO: oriented edge: (Y1,Z2)
# INFO: removed edge: (Y1,Z3)
# INFO: removed edge: (Y2,Z1)
# INFO: oriented edge: (Y2,Z2)
# INFO: removed edge: (Y2,Z3)
# INFO: oriented edge: (Z1,Z2)
# INFO: removed edge: (Z1,Z3)
# INFO: oriented edge: (Z2,Z3)

# %% [markdown]
# ### Comparing CPC implementation to PC baseline

# %%
no_clust = CDAG(no_clust_mapping, no_clust_edges)
no_clust.draw_cluster_graph()
no_clust.cdag_to_mpdag()
no_clust.draw_mpdag()

# %%
# ground truth
draw_graph(nodes, edges)
# Out:
# INFO: oriented edge: (X1,X2)
# INFO: removed edge: (X1,X3)
# INFO: removed edge: (X1,Y1)
# INFO: removed edge: (X1,Y2)
# INFO: oriented edge: (X1,Z1)
# INFO: removed edge: (X1,Z2)
# INFO: removed edge: (X1,Z3)
# INFO: removed edge: (X2,X3)
# INFO: removed edge: (X2,Y1)
# INFO: removed edge: (X2,Y2)
# INFO: removed edge: (X2,Z1)
# INFO: oriented edge: (X2,Z2)
# INFO: removed edge: (X2,Z3)
# INFO: removed edge: (X3,Y1)
# INFO: removed edge: (X3,Y2)
# INFO: removed edge: (X3,Z1)
# INFO: removed edge: (X3,Z2)
# INFO: oriented edge: (X3,Z3)
# INFO: removed edge: (Y1,Y2)
# INFO: oriented edge: (Y1,Z1)
# INFO: oriented edge: (Y1,Z2)
# INFO: removed edge: (Y1,Z3)
# INFO: removed edge: (Y2,Z1)
# INFO: oriented edge: (Y2,Z2)
# INFO: removed edge: (Y2,Z3)
# INFO: oriented edge: (Z1,Z2)
# INFO: removed edge: (Z1,Z3)
# INFO: oriented edge: (Z2,Z3)

# %%
# PC
from causallearn.search.ConstraintBased.PC import pc
causallearn_cg = pc(data)
causallearn_cg.node_names = nodes
causallearn_cg.draw_pydot_graph(labels = nodes)
# Out:
# Depth=4, working on node 7: 100%|██████████| 8/8 [00:00<00:00, 993.97it/s]

# %%
# CPC
# %autoreload 2
clustpc = ClustPC(cdag = no_clust, data = data, alpha = 0.05, \
                  indep_test = "fisherz", \
                  verbose = False, show_progress=True)
clustpc.run()
clustpc.cdag.cg.draw_pydot_graph()
# Out:
# Applying edge orientation rules
# Duration of algorithm was 0.10293221473693848sec

# %%
len(clustpc.cdag.cdag_list_of_topological_sort)
# Out:
# 0

# %%
clustpc.cdag.cdag_topological_sort
# Out:
# <generator object topological_sort at 0x0000025C8F2F68F0>

# %%
list(clustpc.cdag.cluster_mapping.keys())
# Out:
# ['A']
