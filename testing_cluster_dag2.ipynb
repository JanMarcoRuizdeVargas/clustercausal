# %%
# import numpy, pandas, networkx, causallearn, castle
import numpy as np
import pandas as pd
import networkx as nx
import causallearn
import castle
import pydot
import logging

from itertools import combinations
from clustcausal.clusterdag.cluster_dag import CDAG
from causallearn.graph.GraphClass import CausalGraph
from causallearn.utils.PCUtils.BackgroundKnowledge import BackgroundKnowledge

logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')

# %%
cluster_dict = {}
cluster_dict['clusters'] = {'C1':['X1','X2','X3'], 'C2': ['X4','X5'], 'C3':['X6','X7']}
cluster_dict['cluster_edges'] = [('C1','C2'), ('C2','C3')] 
cdag = CDAG(cluster_mapping=cluster_dict['clusters'], cluster_edges = cluster_dict['cluster_edges'])
# Out:
# 2023-06-23 15:21:48,578 - c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\clustcausal\clusterdag\cluster_dag.py[line:69] - INFO: oriented edge: (C1,C2)
# 2023-06-23 15:21:48,579 - c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\clustcausal\clusterdag\cluster_dag.py[line:65] - INFO: removed edge: (C1,C3)
# 2023-06-23 15:21:48,579 - c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\clustcausal\clusterdag\cluster_dag.py[line:69] - INFO: oriented edge: (C2,C3)

# %%
cdag.cdag_to_mpdag()
# Out:
# 2023-06-23 15:21:48,595 - c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\clustcausal\clusterdag\cluster_dag.py[line:95] - INFO: oriented edge: (X1,X4)
# 2023-06-23 15:21:48,595 - c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\clustcausal\clusterdag\cluster_dag.py[line:95] - INFO: oriented edge: (X1,X5)
# 2023-06-23 15:21:48,595 - c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\clustcausal\clusterdag\cluster_dag.py[line:91] - INFO: removed edge: (X1,X6)
# 2023-06-23 15:21:48,595 - c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\clustcausal\clusterdag\cluster_dag.py[line:91] - INFO: removed edge: (X1,X7)
# 2023-06-23 15:21:48,596 - c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\clustcausal\clusterdag\cluster_dag.py[line:95] - INFO: oriented edge: (X2,X4)
# 2023-06-23 15:21:48,596 - c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\clustcausal\clusterdag\cluster_dag.py[line:95] - INFO: oriented edge: (X2,X5)
# 2023-06-23 15:21:48,597 - c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\clustcausal\clusterdag\cluster_dag.py[line:91] - INFO: removed edge: (X2,X6)
# 2023-06-23 15:21:48,598 - c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\clustcausal\clusterdag\cluster_dag.py[line:91] - INFO: removed edge: (X2,X7)
# 2023-06-23 15:21:48,599 - c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\clustcausal\clusterdag\cluster_dag.py[line:95] - INFO: oriented edge: (X3,X4)
# 2023-06-23 15:21:48,600 - c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\clustcausal\clusterdag\cluster_dag.py[line:95] - INFO: oriented edge: (X3,X5)
# 2023-06-23 15:21:48,600 - c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\clustcausal\clusterdag\cluster_dag.py[line:91] - INFO: removed edge: (X3,X6)
# 2023-06-23 15:21:48,601 - c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\clustcausal\clusterdag\cluster_dag.py[line:91] - INFO: removed edge: (X3,X7)
# 2023-06-23 15:21:48,601 - c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\clustcausal\clusterdag\cluster_dag.py[line:95] - INFO: oriented edge: (X4,X6)
# 2023-06-23 15:21:48,602 - c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\clustcausal\clusterdag\cluster_dag.py[line:95] - INFO: oriented edge: (X4,X7)
# 2023-06-23 15:21:48,603 - c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\clustcausal\clusterdag\cluster_dag.py[line:95] - INFO: oriented edge: (X5,X6)
# 2023-06-23 15:21:48,603 - c:\Users\JanMarco\MLProjects\Masterthesis\masterthesis\clustcausal\clusterdag\cluster_dag.py[line:95] - INFO: oriented edge: (X5,X7)

# %%
cdag.cg.draw_pydot_graph()
