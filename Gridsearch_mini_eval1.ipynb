# %%
# %load_ext autoreload
# %autoreload 2
from clustercausal.experiments.ExperimentRunner import ExperimentRunner
import itertools
import yaml
import os
import pickle
import pandas as pd
from clustercausal.utils.Utils import *
pd.set_option('display.max_columns', None)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Load data

# %%
dir = 'clustercausal\experiments\_results\ClusterPC_50nodes50edges_005alpha'
data = load_data(dir)
dir = 'clustercausal\experiments\_results\ClusterPC_50nodes100edges_lin_01alpha'
data = pd.concat([data, load_data(dir)])
dir = 'clustercausal\experiments\_results\ClusterPC_80nodes120edges_lin_01alpha'
data = pd.concat([data, load_data(dir)])
dir = 'clustercausal\experiments\_results\ClusterPC_80nodes120edges_nonlin_01alpha'
data = pd.concat([data, load_data(dir)])
data.shape
# Out:
# (36, 61)

# %%
data.describe()
# Out:
#        base_adj_f1_score  base_adj_false_negative  base_adj_false_positive  \
# count          36.000000                36.000000                36.000000
# mean            0.658856               153.500000                23.027778
# std             0.269115               304.970584                27.769959
# min             0.064660                 3.000000                 0.000000
# 25%             0.630258                12.000000                 8.500000
# 50%             0.768378                23.500000                11.000000
# 75%             0.840619                38.000000                23.750000
# max             0.949495               895.000000               123.000000
#
#        base_adj_precision  base_adj_recall  base_adj_true_negative  \
# count           36.000000        36.000000               36.000000
# mean             0.778770         0.658552             1629.527778
# std              0.134867         0.290259             1019.138025
# ...

# %%
metrics = ['base_adj_precision', 'cluster_adj_precision', 'base_adj_recall', 'cluster_adj_recall', \
           'base_adj_f1_score', 'cluster_adj_f1_score', 'base_base_shd', 'cluster_cluster_shd']
data[metrics].describe()
# Out:
#        base_adj_precision  cluster_adj_precision  base_adj_recall  \
# count           36.000000              36.000000        36.000000
# mean             0.778770               0.734484         0.658552
# std              0.134867               0.139728         0.290259
# min              0.411483               0.362500         0.033760
# 25%              0.716032               0.649382         0.649952
# 50%              0.797959               0.764663         0.755102
# 75%              0.876250               0.841310         0.857143
# max              1.000000               0.986111         0.940000
#
#        cluster_adj_recall  base_adj_f1_score  cluster_adj_f1_score  \
# count           36.000000          36.000000             36.000000
# mean             0.694864           0.658856              0.660547
# std              0.286051           0.269115              0.247042
# min              0.073988           0.064660              0.135021
# ...
