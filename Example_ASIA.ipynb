# %%
import cdt
from cdt.data import load_dataset

# Checking available datasets in your version
# Typical ones are: 'sachs', 'tuebingen', 'dream4-1'
data, graph = load_dataset('sachs') 

# If ASIA is not a built-in string, it is usually 
# imported from bnlearn or pgmpy files:
import pandas as pd
# URL to a common CSV version of the Asia dataset
url = "https://raw.githubusercontent.com/bnlearn-assets/datasets/master/asia.csv"
asia_data = pd.read_csv(url)
# Out:
# No GPU automatically detected. Setting SETTINGS.GPU to 0, and SETTINGS.NJOBS to cpu_count.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[1], line 13
#      11 # URL to a common CSV version of the Asia dataset
#      12 url = "https://raw.githubusercontent.com/bnlearn-assets/datasets/master/asia.csv"
# ---> 13 asia_data = pd.read_csv(url)
#
# File c:\Users\ga87val\00_PhD\000 Paper Development\ClusterDAGs_causal_discovery\clustercausal\env\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...
