# %% [markdown]
# # Gridsearch Cluster all small cdag generation evaluation

# %%
# %load_ext autoreload
# %autoreload 2
from clustercausal.experiments.ExperimentRunner import ExperimentRunner
import itertools
import yaml
import os
import pickle
import pandas as pd
from clustercausal.utils.Utils import *
from clustercausal.experiments.Utils import load_experiment_folder
pd.set_option('display.max_columns', None)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Can take a longer time depending on the numer of experiments, ca. 5sec for 100 experiments
data = load_experiment_folder('clustercausal\experiments\_results\Cluster_PC_small_all_cdag_generation')

# %% [markdown]
# ### Data exploration

# %%
data[:5]
# Out:
#    base_adj_f1_score  base_adj_false_negative  base_adj_false_positive  \
# 0           0.857143                      2.0                      1.0
# 1           1.000000                      0.0                      0.0
# 2           0.818182                      2.0                      2.0
# 3           0.923077                      1.0                      1.0
# 4           0.785714                      0.0                      6.0
#
#    base_adj_precision  base_adj_recall  base_adj_true_negative  \
# 0            0.900000         0.818182                    33.0
# 1            1.000000         1.000000                    39.0
# 2            0.818182         0.818182                    32.0
# 3            0.923077         0.923077                    31.0
# 4            0.647059         1.000000                    28.0
#
#    base_adj_true_positive  base_arrow_f1_score  base_arrow_f1_score_ce  \
# 0                     9.0             0.476190                0.555556
# 1                     6.0             0.600000                0.600000
# 2                     9.0             0.800000                0.941176
# 3                    12.0             0.666667                0.727273
# 4                    11.0             0.560000                0.700000
#
#    base_arrow_false_negative  base_arrow_false_negative_ce  \
# 0                        6.0                           4.0
# 1                        3.0                           3.0
# 2                        3.0                           1.0
# 3                        5.0                           4.0
# 4                        4.0                           4.0
#
#    base_arrow_false_positive  base_arrow_false_positive_ce  \
# 0                        5.0                           4.0
# 1                        1.0                           1.0
# 2                        1.0                           0.0
# 3                        3.0                           2.0
# 4                        7.0                           2.0
#
#    base_arrow_precision  base_arrow_precision_ce  base_arrow_recall  \
# 0              0.500000                 0.555556           0.454545
# 1              0.750000                 0.750000           0.500000
# 2              0.888889                 1.000000           0.727273
# 3              0.727273                 0.800000           0.615385
# 4              0.500000                 0.777778           0.636364
#
#    base_arrow_recall_ce  base_arrow_true_negative  \
# 0              0.555556                      84.0
# 1              0.500000                      93.0
# 2              0.888889                      88.0
# 3              0.666667                      84.0
# 4              0.636364                      82.0
#
#    base_arrow_true_negative_ce  base_arrow_true_positive  \
# 0                         87.0                       5.0
# 1                         93.0                       3.0
# 2                         91.0                       8.0
# 3                         86.0                       8.0
# 4                         87.0                       7.0
#
#    base_arrow_true_positive_ce  base_base_shd  base_sid_lower  \
# 0                          5.0            7.0             NaN
# 1                          3.0            1.0             NaN
# 2                          8.0            4.0             NaN
# 3                          8.0            4.0             NaN
# 4                          7.0            8.0             NaN
#
#    cluster_adj_f1_score  cluster_adj_false_negative  \
# 0              0.857143                         2.0
# 1              1.000000                         0.0
# 2              0.782609                         2.0
# 3              0.962963                         0.0
# 4              0.733333                         0.0
#
#    cluster_adj_false_positive  cluster_adj_precision  cluster_adj_recall  \
# 0                         1.0               0.900000            0.818182
# 1                         0.0               1.000000            1.000000
# 2                         3.0               0.750000            0.818182
# 3                         1.0               0.928571            1.000000
# 4                         8.0               0.578947            1.000000
#
#    cluster_adj_true_negative  cluster_adj_true_positive  \
# 0                       33.0                        9.0
# 1                       39.0                        6.0
# 2                       31.0                        9.0
# 3                       31.0                       13.0
# 4                       26.0                       11.0
#
#    cluster_arrow_f1_score  cluster_arrow_f1_score_ce  \
# 0                0.600000                   0.705882
# 1                0.727273                   0.727273
# 2                0.818182                   1.000000
# 3                0.923077                   0.960000
# 4                0.689655                   0.952381
#
#    cluster_arrow_false_negative  cluster_arrow_false_negative_ce  \
# 0                           5.0                              3.0
# 1                           2.0                              2.0
# 2                           2.0                              0.0
# 3                           1.0                              1.0
# 4                           1.0                              1.0
#
#    cluster_arrow_false_positive  cluster_arrow_false_positive_ce  \
# 0                           3.0                              2.0
# 1                           1.0                              1.0
# 2                           2.0                              0.0
# 3                           1.0                              0.0
# 4                           8.0                              0.0
#
#    cluster_arrow_precision  cluster_arrow_precision_ce  cluster_arrow_recall  \
# 0                 0.666667                        0.75              0.545455
# 1                 0.800000                        0.80              0.666667
# 2                 0.818182                        1.00              0.818182
# 3                 0.923077                        1.00              0.923077
# 4                 0.555556                        1.00              0.909091
#
#    cluster_arrow_recall_ce  cluster_arrow_true_negative  \
# 0                 0.666667                         86.0
# 1                 0.666667                         93.0
# 2                 1.000000                         87.0
# 3                 0.923077                         86.0
# 4                 0.909091                         81.0
#
#    cluster_arrow_true_negative_ce  cluster_arrow_true_positive  \
# 0                            89.0                          6.0
# 1                            93.0                          4.0
# 2                            91.0                          9.0
# 3                            87.0                         12.0
# 4                            89.0                         10.0
#
#    cluster_arrow_true_positive_ce  cluster_cluster_shd  cluster_sid_lower  \
# 0                             6.0                  5.0                NaN
# 1                             4.0                  1.0                NaN
# 2                             9.0                  5.0                NaN
# 3                            12.0                  1.0                NaN
# 4                            10.0                  8.0                NaN
#
#    pruned_base_adj_f1_score  pruned_base_adj_false_negative  \
# 0                  0.857143                             2.0
# 1                  1.000000                             0.0
# 2                  0.818182                             2.0
# 3                  0.923077                             1.0
# 4                  0.785714                             0.0
#
#    pruned_base_adj_false_positive  pruned_base_adj_precision  \
# 0                             1.0                   0.900000
# 1                             0.0                   1.000000
# 2                             2.0                   0.818182
# 3                             1.0                   0.923077
# 4                             6.0                   0.647059
#
#    pruned_base_adj_recall  pruned_base_adj_true_negative  \
# 0                0.818182                           33.0
# 1                1.000000                           39.0
# 2                0.818182                           32.0
# 3                0.923077                           31.0
# 4                1.000000                           28.0
#
#    pruned_base_adj_true_positive  pruned_base_arrow_f1_score  \
# 0                            9.0                    0.476190
# 1                            6.0                    0.600000
# 2                            9.0                    0.800000
# 3                           12.0                    0.666667
# 4                           11.0                    0.560000
#
#    pruned_base_arrow_f1_score_ce  pruned_base_arrow_false_negative  \
# 0                       0.555556                               6.0
# 1                       0.600000                               3.0
# 2                       0.941176                               3.0
# 3                       0.727273                               5.0
# 4                       0.700000                               4.0
#
#    pruned_base_arrow_false_negative_ce  pruned_base_arrow_false_positive  \
# 0                                  4.0                               5.0
# 1                                  3.0                               1.0
# 2                                  1.0                               1.0
# 3                                  4.0                               3.0
# 4                                  4.0                               7.0
#
#    pruned_base_arrow_false_positive_ce  pruned_base_arrow_precision  \
# 0                                  4.0                     0.500000
# 1                                  1.0                     0.750000
# 2                                  0.0                     0.888889
# 3                                  2.0                     0.727273
# 4                                  2.0                     0.500000
#
#    pruned_base_arrow_precision_ce  pruned_base_arrow_recall  \
# 0                        0.555556                  0.454545
# 1                        0.750000                  0.500000
# 2                        1.000000                  0.727273
# 3                        0.800000                  0.615385
# 4                        0.777778                  0.636364
#
#    pruned_base_arrow_recall_ce  pruned_base_arrow_true_negative  \
# 0                     0.555556                             84.0
# 1                     0.500000                             93.0
# 2                     0.888889                             88.0
# 3                     0.666667                             84.0
# 4                     0.636364                             82.0
#
#    pruned_base_arrow_true_negative_ce  pruned_base_arrow_true_positive  \
# 0                                87.0                              5.0
# 1                                93.0                              3.0
# 2                                91.0                              8.0
# 3                                86.0                              8.0
# 4                                87.0                              7.0
#
#    pruned_base_arrow_true_positive_ce  pruned_base_pruned_base_shd  \
# 0                                 5.0                          7.0
# 1                                 3.0                          1.0
# 2                                 8.0                          4.0
# 3                                 8.0                          4.0
# 4                                 7.0                          8.0
#
#    pruned_base_sid_lower  alpha   dag_method distribution_type  \
# 0                    NaN   0.01  erdos_renyi               exp
# 1                    NaN   0.05  erdos_renyi               exp
# 2                    NaN   0.10  erdos_renyi               exp
# 3                    NaN   0.25  erdos_renyi               exp
# 4                    NaN   0.50  erdos_renyi               exp
#
#           edge_ratios  empty_graph_shd indep_test  n_clusters  n_edges  \
# 0  [0.28, 0.12, 0.09]             11.0    fisherz         3.0     10.0
# 1   [0.25, 0.02, 0.0]              6.0    fisherz         3.0     10.0
# 2  [0.32, 0.18, 0.08]             11.0    fisherz         3.0     10.0
# 3   [0.48, 0.22, 0.0]             13.0    fisherz         3.0     10.0
# 4  [0.39, 0.31, 0.17]             11.0    fisherz         3.0     10.0
#
#    n_nodes  noise_scale  sample_size scm_method  seed  true_sid_lower  \
# 0     10.0          1.0       1000.0     linear  None             NaN
# 1     10.0          1.0       1000.0     linear  None             NaN
# 2     10.0          1.0       1000.0     linear  None             NaN
# 3     10.0          1.0       1000.0     linear  None             NaN
# 4     10.0          1.0       1000.0     linear  None             NaN
#
#    true_sid_upper weight_range
# 0             NaN      (-1, 2)
# 1             NaN      (-1, 2)
# 2             NaN      (-1, 2)
# 3             NaN      (-1, 2)
# 4             NaN      (-1, 2)

# %%
data.describe()
# Out:
#        base_adj_f1_score  base_adj_false_negative  base_adj_false_positive  \
# count         405.000000               405.000000               405.000000
# mean            0.783485                 5.538272                 1.276543
# std             0.142349                 6.341880                 1.709776
# min             0.358974                 0.000000                 0.000000
# 25%             0.679245                 1.000000                 0.000000
# 50%             0.800000                 3.000000                 1.000000
# 75%             0.896552                 9.000000                 2.000000
# max             1.000000                26.000000                15.000000
#
#        base_adj_precision  base_adj_recall  base_adj_true_negative  \
# count          405.000000       405.000000              405.000000
# mean             0.890531         0.742608               28.219753
# std              0.140368         0.203450                8.755118
# min              0.250000         0.218750                5.000000
# 25%              0.833333         0.583333               22.000000
# 50%              0.923077         0.764706               30.000000
# 75%              1.000000         0.900000               35.000000
# max              1.000000         1.000000               42.000000
#
#        base_adj_true_positive  base_arrow_f1_score  base_arrow_f1_score_ce  \
# count              405.000000           367.000000              367.000000
# mean                 9.965432             0.403596                0.513209
# std                  3.548642             0.191161                0.194332
# min                  2.000000             0.046512                0.071429
# 25%                  7.000000             0.258065                0.363636
# 50%                 10.000000             0.400000                0.500000
# 75%                 13.000000             0.533333                0.666667
# max                 18.000000             0.947368                1.000000
#
#        base_arrow_false_negative  base_arrow_false_negative_ce  \
# count                 405.000000                    405.000000
# mean                   11.293827                      5.755556
# std                     8.099632                      2.765953
# min                     0.000000                      0.000000
# 25%                     5.000000                      4.000000
# 50%                     9.000000                      5.000000
# 75%                    16.000000                      8.000000
# max                    36.000000                     15.000000
#
#        base_arrow_false_positive  base_arrow_false_positive_ce  \
# count                 405.000000                    405.000000
# mean                    4.360494                      3.251852
# std                     3.443809                      2.811007
# min                     0.000000                      0.000000
# 25%                     1.000000                      1.000000
# 50%                     4.000000                      3.000000
# 75%                     7.000000                      5.000000
# max                    18.000000                     13.000000
#
#        base_arrow_precision  base_arrow_precision_ce  base_arrow_recall  \
# count            386.000000               384.000000         405.000000
# mean               0.530054                 0.593346           0.306759
# std                0.272351                 0.272626           0.199273
# min                0.000000                 0.000000           0.000000
# 25%                0.333333                 0.400000           0.161290
# 50%                0.500000                 0.600000           0.285714
# 75%                0.714286                 0.800000           0.444444
# max                1.000000                 1.000000           1.000000
#
#        base_arrow_recall_ce  base_arrow_true_negative  \
# count            405.000000                405.000000
# mean               0.410659                 80.135802
# std                0.220312                 10.955980
# min                0.000000                 50.000000
# 25%                0.272727                 73.000000
# 50%                0.416667                 82.000000
# 75%                0.571429                 89.000000
# max                1.000000                 97.000000
#
#        base_arrow_true_negative_ce  base_arrow_true_positive  \
# count                   405.000000                405.000000
# mean                     86.782716                  4.209877
# std                       5.853170                  2.568449
# min                      69.000000                  0.000000
# 25%                      83.000000                  2.000000
# 50%                      87.000000                  4.000000
# 75%                      91.000000                  6.000000
# max                      98.000000                 12.000000
#
#        base_arrow_true_positive_ce  base_base_shd  base_sid_lower  \
# count                   405.000000     405.000000             0.0
# mean                      4.209877      10.066667             NaN
# std                       2.568449       8.429557             NaN
# min                       0.000000       0.000000             NaN
# 25%                       2.000000       3.000000             NaN
# 50%                       4.000000       8.000000             NaN
# 75%                       6.000000      15.000000             NaN
# max                      12.000000      34.000000             NaN
#
#        cluster_adj_f1_score  cluster_adj_false_negative  \
# count            405.000000                  405.000000
# mean               0.783947                    5.049383
# std                0.137265                    5.980375
# min                0.357143                    0.000000
# 25%                0.682927                    1.000000
# 50%                0.800000                    3.000000
# 75%                0.888889                    7.000000
# max                1.000000                   26.000000
#
#        cluster_adj_false_positive  cluster_adj_precision  cluster_adj_recall  \
# count                  405.000000             405.000000          405.000000
# mean                     1.928395               0.853343            0.766961
# std                      2.128847               0.150216            0.192238
# min                      0.000000               0.227273            0.250000
# 25%                      0.000000               0.777778            0.629630
# 50%                      1.000000               0.888889            0.785714
# 75%                      3.000000               1.000000            0.916667
# max                     17.000000               1.000000            1.000000
#
#        cluster_adj_true_negative  cluster_adj_true_positive  \
# count                 405.000000                 405.000000
# mean                   27.567901                  10.454321
# std                     9.062405                   3.946550
# min                     5.000000                   2.000000
# 25%                    22.000000                   8.000000
# 50%                    30.000000                  10.000000
# 75%                    35.000000                  13.000000
# max                    42.000000                  20.000000
#
#        cluster_arrow_f1_score  cluster_arrow_f1_score_ce  \
# count              397.000000                 397.000000
# mean                 0.589137                   0.753705
# std                  0.183024                   0.166098
# min                  0.125000                   0.200000
# 25%                  0.448980                   0.666667
# 50%                  0.600000                   0.782609
# 75%                  0.720000                   0.880000
# max                  1.000000                   1.000000
#
#        cluster_arrow_false_negative  cluster_arrow_false_negative_ce  \
# count                    405.000000                       405.000000
# mean                       8.158025                         3.108642
# std                        6.937466                         1.958240
# min                        0.000000                         0.000000
# 25%                        3.000000                         2.000000
# 50%                        6.000000                         3.000000
# 75%                       11.000000                         4.000000
# max                       31.000000                        10.000000
#
#        cluster_arrow_false_positive  cluster_arrow_false_positive_ce  \
# count                    405.000000                       405.000000
# mean                       3.362963                         1.540741
# std                        2.857007                         1.756584
# min                        0.000000                         0.000000
# 25%                        1.000000                         0.000000
# 50%                        3.000000                         1.000000
# 75%                        5.000000                         2.000000
# max                       18.000000                         9.000000
#
#        cluster_arrow_precision  cluster_arrow_precision_ce  \
# count               402.000000                  400.000000
# mean                  0.705527                    0.840573
# std                   0.216163                    0.176917
# min                   0.000000                    0.000000
# 25%                   0.571429                    0.745833
# 50%                   0.727273                    0.888889
# 75%                   0.857143                    1.000000
# max                   1.000000                    1.000000
#
#        cluster_arrow_recall  cluster_arrow_recall_ce  \
# count            405.000000               405.000000
# mean               0.522670                 0.682877
# std                0.215557                 0.205826
# min                0.000000                 0.000000
# 25%                0.357143                 0.571429
# 50%                0.526316                 0.714286
# 75%                0.666667                 0.823529
# max                1.000000                 1.000000
#
#        cluster_arrow_true_negative  cluster_arrow_true_negative_ce  \
# count                   405.000000                      405.000000
# mean                     81.133333                       88.004938
# std                      10.219231                        5.069319
# min                      52.000000                       74.000000
# 25%                      74.000000                       84.000000
# 50%                      83.000000                       88.000000
# 75%                      89.000000                       92.000000
# max                      98.000000                       98.000000
#
#        cluster_arrow_true_positive  cluster_arrow_true_positive_ce  \
# count                   405.000000                      405.000000
# mean                      7.345679                        7.345679
# std                       3.531893                        3.531893
# min                       0.000000                        0.000000
# 25%                       5.000000                        5.000000
# 50%                       7.000000                        7.000000
# 75%                      10.000000                       10.000000
# max                      17.000000                       17.000000
#
#        cluster_cluster_shd  cluster_sid_lower  pruned_base_adj_f1_score  \
# count           405.000000                0.0                405.000000
# mean              8.518519                NaN                  0.783485
# std               7.451678                NaN                  0.142349
# min               0.000000                NaN                  0.358974
# 25%               3.000000                NaN                  0.679245
# 50%               6.000000                NaN                  0.800000
# 75%              12.000000                NaN                  0.896552
# max              33.000000                NaN                  1.000000
#
#        pruned_base_adj_false_negative  pruned_base_adj_false_positive  \
# count                      405.000000                      405.000000
# mean                         5.538272                        1.276543
# std                          6.341880                        1.709776
# min                          0.000000                        0.000000
# 25%                          1.000000                        0.000000
# 50%                          3.000000                        1.000000
# 75%                          9.000000                        2.000000
# max                         26.000000                       15.000000
#
#        pruned_base_adj_precision  pruned_base_adj_recall  \
# count                 405.000000              405.000000
# mean                    0.890531                0.742608
# std                     0.140368                0.203450
# min                     0.250000                0.218750
# 25%                     0.833333                0.583333
# 50%                     0.923077                0.764706
# 75%                     1.000000                0.900000
# max                     1.000000                1.000000
#
#        pruned_base_adj_true_negative  pruned_base_adj_true_positive  \
# count                     405.000000                     405.000000
# mean                       28.219753                       9.965432
# std                         8.755118                       3.548642
# min                         5.000000                       2.000000
# 25%                        22.000000                       7.000000
# 50%                        30.000000                      10.000000
# 75%                        35.000000                      13.000000
# max                        42.000000                      18.000000
#
#        pruned_base_arrow_f1_score  pruned_base_arrow_f1_score_ce  \
# count                  367.000000                     367.000000
# mean                     0.403596                       0.513209
# std                      0.191161                       0.194332
# min                      0.046512                       0.071429
# 25%                      0.258065                       0.363636
# 50%                      0.400000                       0.500000
# 75%                      0.533333                       0.666667
# max                      0.947368                       1.000000
#
#        pruned_base_arrow_false_negative  pruned_base_arrow_false_negative_ce  \
# count                        405.000000                           405.000000
# mean                          11.293827                             5.755556
# std                            8.099632                             2.765953
# min                            0.000000                             0.000000
# 25%                            5.000000                             4.000000
# 50%                            9.000000                             5.000000
# 75%                           16.000000                             8.000000
# max                           36.000000                            15.000000
#
#        pruned_base_arrow_false_positive  pruned_base_arrow_false_positive_ce  \
# count                        405.000000                           405.000000
# mean                           4.360494                             3.251852
# std                            3.443809                             2.811007
# min                            0.000000                             0.000000
# 25%                            1.000000                             1.000000
# 50%                            4.000000                             3.000000
# 75%                            7.000000                             5.000000
# max                           18.000000                            13.000000
#
#        pruned_base_arrow_precision  pruned_base_arrow_precision_ce  \
# count                   386.000000                      384.000000
# mean                      0.530054                        0.593346
# std                       0.272351                        0.272626
# min                       0.000000                        0.000000
# 25%                       0.333333                        0.400000
# 50%                       0.500000                        0.600000
# 75%                       0.714286                        0.800000
# max                       1.000000                        1.000000
#
#        pruned_base_arrow_recall  pruned_base_arrow_recall_ce  \
# count                405.000000                   405.000000
# mean                   0.306759                     0.410659
# std                    0.199273                     0.220312
# min                    0.000000                     0.000000
# 25%                    0.161290                     0.272727
# 50%                    0.285714                     0.416667
# 75%                    0.444444                     0.571429
# max                    1.000000                     1.000000
#
#        pruned_base_arrow_true_negative  pruned_base_arrow_true_negative_ce  \
# count                       405.000000                          405.000000
# mean                         80.135802                           86.782716
# std                          10.955980                            5.853170
# min                          50.000000                           69.000000
# 25%                          73.000000                           83.000000
# 50%                          82.000000                           87.000000
# 75%                          89.000000                           91.000000
# max                          97.000000                           98.000000
#
#        pruned_base_arrow_true_positive  pruned_base_arrow_true_positive_ce  \
# count                       405.000000                          405.000000
# mean                          4.209877                            4.209877
# std                           2.568449                            2.568449
# min                           0.000000                            0.000000
# 25%                           2.000000                            2.000000
# 50%                           4.000000                            4.000000
# 75%                           6.000000                            6.000000
# max                          12.000000                           12.000000
#
#        pruned_base_pruned_base_shd  pruned_base_sid_lower       alpha  \
# count                   405.000000                    0.0  405.000000
# mean                     10.066667                    NaN    0.182000
# std                       8.429557                    NaN    0.178815
# min                       0.000000                    NaN    0.010000
# 25%                       3.000000                    NaN    0.050000
# 50%                       8.000000                    NaN    0.100000
# 75%                      15.000000                    NaN    0.250000
# max                      34.000000                    NaN    0.500000
#
#        empty_graph_shd  n_clusters     n_edges  n_nodes  noise_scale  \
# count       405.000000  405.000000  405.000000    405.0        405.0
# mean         15.503704    4.000000   20.000000     10.0          1.0
# std           8.743490    0.817506    8.175065      0.0          0.0
# min           2.000000    3.000000   10.000000     10.0          1.0
# 25%           9.000000    3.000000   10.000000     10.0          1.0
# 50%          14.000000    4.000000   20.000000     10.0          1.0
# 75%          21.000000    5.000000   30.000000     10.0          1.0
# max          38.000000    5.000000   30.000000     10.0          1.0
#
#        sample_size  true_sid_lower  true_sid_upper
# count        405.0             0.0             0.0
# mean        1000.0             NaN             NaN
# std            0.0             NaN             NaN
# min         1000.0             NaN             NaN
# 25%         1000.0             NaN             NaN
# 50%         1000.0             NaN             NaN
# 75%         1000.0             NaN             NaN
# max         1000.0             NaN             NaN

# %%
prec_recall_metrics = ['base_adj_precision', 'pruned_base_adj_precision', 'cluster_adj_precision', \
           'base_adj_recall', 'pruned_base_adj_recall','cluster_adj_recall', \
           'base_adj_f1_score', 'pruned_base_adj_f1_score', 'cluster_adj_f1_score']
data[prec_recall_metrics].describe()
# Out:
#        base_adj_precision  pruned_base_adj_precision  cluster_adj_precision  \
# count          405.000000                 405.000000             405.000000
# mean             0.890531                   0.890531               0.853343
# std              0.140368                   0.140368               0.150216
# min              0.250000                   0.250000               0.227273
# 25%              0.833333                   0.833333               0.777778
# 50%              0.923077                   0.923077               0.888889
# 75%              1.000000                   1.000000               1.000000
# max              1.000000                   1.000000               1.000000
#
#        base_adj_recall  pruned_base_adj_recall  cluster_adj_recall  \
# count       405.000000              405.000000          405.000000
# mean          0.742608                0.742608            0.766961
# std           0.203450                0.203450            0.192238
# min           0.218750                0.218750            0.250000
# 25%           0.583333                0.583333            0.629630
# 50%           0.764706                0.764706            0.785714
# 75%           0.900000                0.900000            0.916667
# max           1.000000                1.000000            1.000000
#
#        base_adj_f1_score  pruned_base_adj_f1_score  cluster_adj_f1_score
# count         405.000000                405.000000            405.000000
# mean            0.783485                  0.783485              0.783947
# std             0.142349                  0.142349              0.137265
# min             0.358974                  0.358974              0.357143
# 25%             0.679245                  0.679245              0.682927
# 50%             0.800000                  0.800000              0.800000
# 75%             0.896552                  0.896552              0.888889
# max             1.000000                  1.000000              1.000000

# %%
count_metrics = ['base_adj_false_negative', 'pruned_base_adj_false_negative', 'cluster_adj_false_negative', \
                 'base_adj_false_positive', 'pruned_base_adj_false_positive','cluster_adj_false_positive', \
                    'base_adj_true_negative', 'pruned_base_adj_true_negative', 'cluster_adj_true_negative', \
                        'base_adj_true_positive', 'pruned_base_adj_true_positive', 'cluster_adj_true_positive']
data[count_metrics]
# Out:
#      base_adj_false_negative  pruned_base_adj_false_negative  \
# 0                        2.0                             2.0
# 1                        0.0                             0.0
# 2                        2.0                             2.0
# 3                        1.0                             1.0
# 4                        0.0                             0.0
# ..                       ...                             ...
# 400                      2.0                             2.0
# 401                      1.0                             1.0
# 402                      1.0                             1.0
# 403                     11.0                            11.0
# 404                      8.0                             8.0
#
#      cluster_adj_false_negative  base_adj_false_positive  \
# 0                           2.0                      1.0
# 1                           0.0                      0.0
# 2                           2.0                      2.0
# 3                           0.0                      1.0
# 4                           0.0                      6.0
# ..                          ...                      ...
# 400                         2.0                      0.0
# 401                         1.0                      0.0
# 402                         0.0                      0.0
# 403                         5.0                      1.0
# 404                         5.0                      0.0
#
#      pruned_base_adj_false_positive  cluster_adj_false_positive  \
# 0                               1.0                         1.0
# 1                               0.0                         0.0
# 2                               2.0                         3.0
# 3                               1.0                         1.0
# 4                               6.0                         8.0
# ..                              ...                         ...
# 400                             0.0                         0.0
# 401                             0.0                         0.0
# 402                             0.0                         0.0
# 403                             1.0                         1.0
# 404                             0.0                         1.0
#
#      base_adj_true_negative  pruned_base_adj_true_negative  \
# 0                      33.0                           33.0
# 1                      39.0                           39.0
# 2                      32.0                           32.0
# 3                      31.0                           31.0
# 4                      28.0                           28.0
# ..                      ...                            ...
# 400                    39.0                           39.0
# 401                    35.0                           35.0
# 402                    35.0                           35.0
# 403                    21.0                           21.0
# 404                    22.0                           22.0
#
#      cluster_adj_true_negative  base_adj_true_positive  \
# 0                         33.0                     9.0
# 1                         39.0                     6.0
# 2                         31.0                     9.0
# 3                         31.0                    12.0
# 4                         26.0                    11.0
# ..                         ...                     ...
# 400                       39.0                     4.0
# 401                       35.0                     9.0
# 402                       35.0                     9.0
# 403                       21.0                    12.0
# 404                       21.0                    15.0
#
#      pruned_base_adj_true_positive  cluster_adj_true_positive
# 0                              9.0                        9.0
# 1                              6.0                        6.0
# 2                              9.0                        9.0
# 3                             12.0                       13.0
# 4                             11.0                       11.0
# ..                             ...                        ...
# 400                            4.0                        4.0
# 401                            9.0                        9.0
# 402                            9.0                       10.0
# 403                           12.0                       18.0
# 404                           15.0                       18.0
#
# [405 rows x 12 columns]

# %%
dist_metrics = ['base_base_shd', 'pruned_base_pruned_base_shd', 'cluster_cluster_shd']#, \
         #   'base_sid_lower', 'base_sid_upper', 'pruned_base_sid_lower', 'pruned_base_sid_upper', \
         #      'cluster_sid_lower', 'cluster_sid_upper']
data[dist_metrics].describe()
# Out:
#        base_base_shd  pruned_base_pruned_base_shd  cluster_cluster_shd
# count     405.000000                   405.000000           405.000000
# mean       10.066667                    10.066667             8.518519
# std         8.429557                     8.429557             7.451678
# min         0.000000                     0.000000             0.000000
# 25%         3.000000                     3.000000             3.000000
# 50%         8.000000                     8.000000             6.000000
# 75%        15.000000                    15.000000            12.000000
# max        34.000000                    34.000000            33.000000

# %%
edge_ratios = data['edge_ratios'].apply(pd.Series)
edge_ratios.columns = ['intra_cluster', 'inter_cluster', 'inter_including_disconnected_cluster']
mean_values = edge_ratios.mean()
mean_values = pd.DataFrame([mean_values])
print('Edge Ratios \n', mean_values)
# Out:
# Edge Ratios
#     intra_cluster  inter_cluster  inter_including_disconnected_cluster
# 0       0.611432        0.34139                              0.120568

# %% [markdown]
# ### Comparing true & false positives and true & false negatives

# %%
true_false_positive_metrics = ['base_adj_true_positive', 'pruned_base_adj_true_positive', 'cluster_adj_true_positive', \
                          'base_adj_false_positive', 'pruned_base_adj_false_positive','cluster_adj_false_positive']

true_false_negative_metrics = ['base_adj_true_negative', 'pruned_base_adj_true_negative', 'cluster_adj_true_negative', \
                          'base_adj_false_negative', 'pruned_base_adj_false_negative', 'cluster_adj_false_negative']

true_false_metrics = ['base_adj_true_positive', 'pruned_base_adj_true_positive', 'cluster_adj_true_positive', \
                    'base_adj_true_negative', 'pruned_base_adj_true_negative', 'cluster_adj_true_negative', \
                    'base_adj_false_positive', 'pruned_base_adj_false_positive','cluster_adj_false_positive', \
                    'base_adj_false_negative', 'pruned_base_adj_false_negative', 'cluster_adj_false_negative']

# %%
data[true_false_positive_metrics].describe()
# Out:
#        base_adj_true_positive  pruned_base_adj_true_positive  \
# count              405.000000                     405.000000
# mean                 9.965432                       9.965432
# std                  3.548642                       3.548642
# min                  2.000000                       2.000000
# 25%                  7.000000                       7.000000
# 50%                 10.000000                      10.000000
# 75%                 13.000000                      13.000000
# max                 18.000000                      18.000000
#
#        cluster_adj_true_positive  base_adj_false_positive  \
# count                 405.000000               405.000000
# mean                   10.454321                 1.276543
# std                     3.946550                 1.709776
# min                     2.000000                 0.000000
# 25%                     8.000000                 0.000000
# 50%                    10.000000                 1.000000
# 75%                    13.000000                 2.000000
# max                    20.000000                15.000000
#
#        pruned_base_adj_false_positive  cluster_adj_false_positive
# count                      405.000000                  405.000000
# mean                         1.276543                    1.928395
# std                          1.709776                    2.128847
# min                          0.000000                    0.000000
# 25%                          0.000000                    0.000000
# 50%                          1.000000                    1.000000
# 75%                          2.000000                    3.000000
# max                         15.000000                   17.000000

# %%
data[true_false_negative_metrics].describe()
# Out:
#        base_adj_true_negative  pruned_base_adj_true_negative  \
# count              405.000000                     405.000000
# mean                28.219753                      28.219753
# std                  8.755118                       8.755118
# min                  5.000000                       5.000000
# 25%                 22.000000                      22.000000
# 50%                 30.000000                      30.000000
# 75%                 35.000000                      35.000000
# max                 42.000000                      42.000000
#
#        cluster_adj_true_negative  base_adj_false_negative  \
# count                 405.000000               405.000000
# mean                   27.567901                 5.538272
# std                     9.062405                 6.341880
# min                     5.000000                 0.000000
# 25%                    22.000000                 1.000000
# 50%                    30.000000                 3.000000
# 75%                    35.000000                 9.000000
# max                    42.000000                26.000000
#
#        pruned_base_adj_false_negative  cluster_adj_false_negative
# count                      405.000000                  405.000000
# mean                         5.538272                    5.049383
# std                          6.341880                    5.980375
# min                          0.000000                    0.000000
# 25%                          1.000000                    1.000000
# 50%                          3.000000                    3.000000
# 75%                          9.000000                    7.000000
# max                         26.000000                   26.000000

# %% [markdown]
# ### Comparing total true and false

# %%
data['base_total_true'] = data['base_adj_true_positive'] + data['base_adj_true_negative']
data['base_total_false'] = data['base_adj_false_positive'] + data['base_adj_false_negative']
data['pruned_base_total_true'] = data['pruned_base_adj_true_positive'] + data['pruned_base_adj_true_negative']
data['pruned_base_total_false'] = data['pruned_base_adj_false_positive'] + data['pruned_base_adj_false_negative']
data['cluster_total_true'] = data['cluster_adj_true_positive'] + data['cluster_adj_true_negative']
data['cluster_total_false'] = data['cluster_adj_false_positive'] + data['cluster_adj_false_negative']
total_true_false_metrics = ['base_total_true', 'pruned_base_total_true', 'cluster_total_true', \
                    'base_total_false', 'pruned_base_total_false', 'cluster_total_false']
data[total_true_false_metrics].describe()
# Out:
#        base_total_true  pruned_base_total_true  cluster_total_true  \
# count       405.000000              405.000000          405.000000
# mean         38.185185               38.185185           38.022222
# std           6.467572                6.467572            6.426045
# min          17.000000               17.000000           16.000000
# 25%          35.000000               35.000000           35.000000
# 50%          40.000000               40.000000           40.000000
# 75%          43.000000               43.000000           43.000000
# max          45.000000               45.000000           45.000000
#
#        base_total_false  pruned_base_total_false  cluster_total_false
# count        405.000000               405.000000           405.000000
# mean           6.814815                 6.814815             6.977778
# std            6.467572                 6.467572             6.426045
# min            0.000000                 0.000000             0.000000
# 25%            2.000000                 2.000000             2.000000
# 50%            5.000000                 5.000000             5.000000
# 75%           10.000000                10.000000            10.000000
# max           28.000000                28.000000            29.000000

# %% [markdown]
# ### Grouping by clusters

# %%
data.groupby('n_clusters').mean()[prec_recall_metrics]
# Out:
#             base_adj_precision  pruned_base_adj_precision  \
# n_clusters
# 3.0                   0.887327                   0.887327
# 4.0                   0.897321                   0.897321
# 5.0                   0.886944                   0.886944
#
#             cluster_adj_precision  base_adj_recall  pruned_base_adj_recall  \
# n_clusters
# 3.0                      0.847485         0.638959                0.638959
# 4.0                      0.860628         0.756112                0.756112
# 5.0                      0.851915         0.832752                0.832752
#
#             cluster_adj_recall  base_adj_f1_score  pruned_base_adj_f1_score  \
# n_clusters
# 3.0                   0.664867           0.712525                  0.712525
# 4.0                   0.780943           0.798944                  0.798944
# 5.0                   0.855074           0.838984                  0.838984
#
#             cluster_adj_f1_score
# n_clusters
# 3.0                     0.716956
# 4.0                     0.799493
# 5.0                     0.835393

# %%
data.groupby('n_clusters').mean()[dist_metrics]
# Out:
#             base_base_shd  pruned_base_pruned_base_shd  cluster_cluster_shd
# n_clusters
# 3.0             15.629630                    15.629630            13.651852
# 4.0              9.125926                     9.125926             7.533333
# 5.0              5.444444                     5.444444             4.370370

# %% [markdown]
# ### Grouping by alpha

# %%
data.groupby('alpha').mean()[prec_recall_metrics]
# Out:
#        base_adj_precision  pruned_base_adj_precision  cluster_adj_precision  \
# alpha
# 0.01             0.958033                   0.958033               0.937177
# 0.05             0.954070                   0.954070               0.918556
# 0.10             0.921698                   0.921698               0.894890
# 0.25             0.843904                   0.843904               0.795563
# 0.50             0.774949                   0.774949               0.720527
#
#        base_adj_recall  pruned_base_adj_recall  cluster_adj_recall  \
# alpha
# 0.01          0.688782                0.688782            0.711061
# 0.05          0.728589                0.728589            0.758288
# 0.10          0.734475                0.734475            0.757186
# 0.25          0.770838                0.770838            0.790117
# 0.50          0.790354                0.790354            0.818156
#
#        base_adj_f1_score  pruned_base_adj_f1_score  cluster_adj_f1_score
# alpha
# 0.01            0.782781                  0.782781              0.794353
# 0.05            0.809108                  0.809108              0.817967
# 0.10            0.795698                  0.795698              0.800265
# 0.25            0.777819                  0.777819              0.769413
# 0.50            0.752016                  0.752016              0.737739

# %%
data.groupby('alpha').mean()[dist_metrics]
# Out:
#        base_base_shd  pruned_base_pruned_base_shd  cluster_cluster_shd
# alpha
# 0.01        9.160494                     9.160494             8.012346
# 0.05        8.925926                     8.925926             7.506173
# 0.10        9.506173                     9.506173             8.098765
# 0.25       10.641975                    10.641975             9.000000
# 0.50       12.098765                    12.098765             9.975309

# %% [markdown]
# ### Grouping by distribution type

# %%
data.groupby('distribution_type').mean()[prec_recall_metrics]
# Out:
#                    base_adj_precision  pruned_base_adj_precision  \
# distribution_type
# exp                          0.889007                   0.889007
# gauss                        0.879523                   0.879523
# gumbel                       0.903063                   0.903063
#
#                    cluster_adj_precision  base_adj_recall  \
# distribution_type
# exp                             0.854025         0.745791
# gauss                           0.840798         0.736700
# gumbel                          0.865205         0.745331
#
#                    pruned_base_adj_recall  cluster_adj_recall  \
# distribution_type
# exp                              0.745791            0.770044
# gauss                            0.736700            0.756173
# gumbel                           0.745331            0.774667
#
#                    base_adj_f1_score  pruned_base_adj_f1_score  \
# distribution_type
# exp                         0.785019                  0.785019
# gauss                       0.775925                  0.775925
# gumbel                      0.789511                  0.789511
#
#                    cluster_adj_f1_score
# distribution_type
# exp                            0.786114
# gauss                          0.772433
# gumbel                         0.793295

# %%
data.groupby('distribution_type').mean()[dist_metrics]
# Out:
#                    base_base_shd  pruned_base_pruned_base_shd  \
# distribution_type
# exp                     9.940741                     9.940741
# gauss                  10.488889                    10.488889
# gumbel                  9.770370                     9.770370
#
#                    cluster_cluster_shd
# distribution_type
# exp                           8.318519
# gauss                         9.051852
# gumbel                        8.185185

# %% [markdown]
# ### Grouping by DAG method

# %%
data.groupby('dag_method').mean()[prec_recall_metrics]
# Out:
#               base_adj_precision  pruned_base_adj_precision  \
# dag_method
# erdos_renyi             0.874881                   0.874881
# hierarchical            0.889255                   0.889255
# scale_free              0.907457                   0.907457
#
#               cluster_adj_precision  base_adj_recall  pruned_base_adj_recall  \
# dag_method
# erdos_renyi                0.839368         0.744863                0.744863
# hierarchical               0.854330         0.739625                0.739625
# scale_free                 0.866330         0.743335                0.743335
#
#               cluster_adj_recall  base_adj_f1_score  pruned_base_adj_f1_score  \
# dag_method
# erdos_renyi             0.767641           0.776211                  0.776211
# hierarchical            0.763057           0.776326                  0.776326
# scale_free              0.770187           0.797917                  0.797917
#
#               cluster_adj_f1_score
# dag_method
# erdos_renyi               0.777309
# hierarchical              0.777468
# scale_free                0.797064

# %%
data.groupby('dag_method').mean()[dist_metrics]
# Out:
#               base_base_shd  pruned_base_pruned_base_shd  cluster_cluster_shd
# dag_method
# erdos_renyi        9.911111                     9.911111             8.518519
# hierarchical      10.533333                    10.533333             8.792593
# scale_free         9.755556                     9.755556             8.244444

# %% [markdown]
# ### Grouping by #clusters

# %%
data.groupby('n_clusters').mean()[prec_recall_metrics]
# Out:
#             base_adj_precision  pruned_base_adj_precision  \
# n_clusters
# 3.0                   0.887327                   0.887327
# 4.0                   0.897321                   0.897321
# 5.0                   0.886944                   0.886944
#
#             cluster_adj_precision  base_adj_recall  pruned_base_adj_recall  \
# n_clusters
# 3.0                      0.847485         0.638959                0.638959
# 4.0                      0.860628         0.756112                0.756112
# 5.0                      0.851915         0.832752                0.832752
#
#             cluster_adj_recall  base_adj_f1_score  pruned_base_adj_f1_score  \
# n_clusters
# 3.0                   0.664867           0.712525                  0.712525
# 4.0                   0.780943           0.798944                  0.798944
# 5.0                   0.855074           0.838984                  0.838984
#
#             cluster_adj_f1_score
# n_clusters
# 3.0                     0.716956
# 4.0                     0.799493
# 5.0                     0.835393

# %%
data.groupby('n_clusters').mean()[dist_metrics]
# Out:
#             base_base_shd  pruned_base_pruned_base_shd  cluster_cluster_shd
# n_clusters
# 3.0             15.629630                    15.629630            13.651852
# 4.0              9.125926                     9.125926             7.533333
# 5.0              5.444444                     5.444444             4.370370

# %% [markdown]
# ### Grouping by #edges

# %%
data.groupby('n_edges').mean()[prec_recall_metrics]
# Out:
#          base_adj_precision  pruned_base_adj_precision  cluster_adj_precision  \
# n_edges
# 10.0               0.823879                   0.823879               0.789568
# 20.0               0.913922                   0.913922               0.878894
# 30.0               0.933791                   0.933791               0.891566
#
#          base_adj_recall  pruned_base_adj_recall  cluster_adj_recall  \
# n_edges
# 10.0            0.914160                0.914160            0.924946
# 20.0            0.734430                0.734430            0.757867
# 30.0            0.579233                0.579233            0.618071
#
#          base_adj_f1_score  pruned_base_adj_f1_score  cluster_adj_f1_score
# n_edges
# 10.0              0.847805                  0.847805              0.831357
# 20.0              0.803249                  0.803249              0.803903
# 30.0              0.699400                  0.699400              0.716582

# %%
data.groupby('n_edges').mean()[dist_metrics]
# Out:
#          base_base_shd  pruned_base_pruned_base_shd  cluster_cluster_shd
# n_edges
# 10.0          4.177778                     4.177778             3.755556
# 20.0          9.081481                     9.081481             7.562963
# 30.0         16.940741                    16.940741            14.237037
